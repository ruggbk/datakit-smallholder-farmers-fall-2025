# %%
import pandas as pd
import numpy as np
from dotenv import load_dotenv
import os
import duckdb
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans, HDBSCAN
from sklearn.metrics import silhouette_score, davies_bouldin_score
from sklearn.metrics.pairwise import cosine_similarity
import umap
import nltk
import re
from sentence_transformers import SentenceTransformer

# Import from local modules
import sys
sys.path.append('../src')

from cleaning import minimal_clean, clean_text, tokenize, lemmatize_tokens

# Download necessary NLTK resources
import nltk
nltk.download('wordnet')
nltk.download('stopwords')

# Path for 1 million English sample questions
load_dotenv()
sample_path = os.getenv("DATA_SAMPLE")
full_data_path = os.getenv("DATA_PARQUET")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ruggb\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ruggb\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Clustering on question content (English)

# %% [markdown]
# ### Prepare sample dataset

# %%
dataset = pd.read_parquet(sample_path)

# Drop duplicate questions
questions_raw = dataset.drop_duplicates(subset='question_content', keep='first')

# Random sample of rows, reproducible with random_state
questions = questions_raw.sample(n=100000, random_state=42)

# %%
questions_raw.shape
# Out:
# (737315, 24)

# %%
questions['question_topic']
# Out:
# 725489         bird
# 302816        maize
# 388150         bean
# 49371          kale
# 293923       cattle
#             ...
# 441257         crop
# 566298         None
# 676477         None
# 787574          pig
# 656249    vegetable
# Name: question_topic, Length: 100000, dtype: object

# %%
pd.unique(questions_raw['question_topic'])
# Out:
# array([None, 'plant', 'maize', 'cattle', 'bean', 'goat', 'duck',
#        'pumpkin', 'animal', 'grass', 'chicken', 'rabbit', 'tomato',
#        'melon', 'peanut', 'crop', 'coffee', 'paw-paw', 'wheat', 'millet',
#        'poultry', 'onion', 'potato', 'apple', 'pig', 'bird', 'eucalyptus',
#        'fish', 'aubergine', 'kale', 'livestock', 'dog', 'pigeon',
#        'cabbage', 'banana', 'french-bean', 'sheep', 'avocado', 'bee',
#        'cassava', 'capsicum', 'rice', 'pear', 'tea', 'cotton',
#        'macademia', 'plantain', 'tobacco', 'yam', 'tree', 'taro',
#        'radish', 'watermelon', 'greens', 'sweet-potato', 'vegetable',
#        'olive', 'passion-fruit', 'napier-grass', 'pea', 'orange',
#        'sunflower', 'carrot', 'lemon', 'miraa', 'cat', 'soya', 'lettuce',
#        'ginger', 'cowpea', 'sugar-cane', 'pineapple', 'jackfruit',
#        'mango', 'sisal', 'spinach', 'okra', 'mushroom', 'garlic',
#        'turkey', 'peach', 'collard-greens', 'cereal', 'corriander',
#        'butternut-squash', 'bamboo', 'beetroot', 'cocoa', 'camel',
#        'safflower', 'cashew-nut', 'snow-pea', 'clover', 'flax', 'locust',
#        'guava', 'grape', 'strawberry', 'mung-bean', 'courgette',
#        'pyrethrum', 'squash', 'tilapia', 'chilli', 'gooseberry',
#        'black-nightshade', 'cucumber', 'lucern', 'desmodium', 'amaranth',
#        'african-nightshade', 'chia', 'finger-millet', 'rapeseed', 'oat',
#        'nightshade', 'chard', 'leek', 'boma-rhodes', 'broccoli', 'cyprus',
#        'parsley', 'coconut', 'brachiaria-grass', 'guinea-fowl', 'barley',
#        'guinea-pig', 'asparagus', 'sudan-grass', 'caliandra',
#        'pigeon-pea', 'apricot', 'snap-pea', 'celery', 'sesame', 'lupin',
#        'acacia', 'rye', 'cauliflower', 'ostrich', 'leucaena', 'vetch',
#        'purple-vetch', 'chickpea', 'castor-bean', 'mulberry', 'setaria',
#        'blackberry', 'cranberry'], dtype=object)

# %%
questions_raw.shape
# Out:
# (737315, 24)

# %%
for question in questions['question_content'].head(10):
    print(question)
    print("-----")
# Out:
# Q how can I do so as my birds can multiply  faster  as I use the traditional method  ? Or is it advisable immediately after hatching I separate the chicks and mother?
# -----
# How can l control maize stalk ?
# -----
# Q, Wht Iz Da Cost Ov 1 Kg Of Beans
# -----
# I have ready sukuma wiki for in siaya. Connect me with the buyers
# -----
# which is the best option between buying either of this grade cows(not pedigrees):18month old heifer, mature heifer,incalf heifer or lactating dairy cow?
# -----
# I Know to plant banana plantation
# -----
# What is the best soil to plant tobacco
# -----
# The best acaricide to spray cows is ALMATICKS
# -----
# Which disease for hens is characterized by crying eyes and wounds around the head
# -----
# Q HOW MENY TYPES OF MILET DO WE HAVE? ASK ME ABOUT TOMATO.
# -----

# %%
# Case-insensitive filtering
filtered_questions = questions.loc[
    questions['question_content'].str.contains("asks", case=False, na=False)
]

# Get the first N questions that contain "asks"
N = 30
sample_questions = filtered_questions.head(N)

# Print them
for question in sample_questions['question_content']:
    print(question)
    print("-----")
# Out:
# QA farmer asks: Whats is the use of pigs fichtes in our farm? Reply Q348 followed by your response.
#
# optout stop 6333
# -----
# Edward asks: I would like to know the pineapple disease Reply Q39 followed by your response.
#
# optout stop 6333
# -----
# A farmer asks: Am planing 2grow millet in a swampy area. How can i grow it Reply Q571 followed by your response.
# -----
# Joseph asks: where can i get/purchase a good pedigree dairy expectant heifer?..plse assist.thx. Reply Q14 followed by your response. at nandi county
# -----
# Emma Asks:what Is Cover Crops? Reply P7 Followed By Your Response.
# -----
# A farmer asks: which breed is the best of cow and where can i get Reply Q182 followed by your response.
# -----
# Beatrice asks: How Can One Determine The Age Of A Tree Plant? Reply Q816 followed by your response.
# -----
# Q A farmer asks: how do we plant passion fruits Reply Q477 followed by your response.
#
# optout stop 6333
# -----
# Joel asks: HOW MANY MONTH THAT IS SUPPOSSED TO HARVEST CABBAGES Reply Q293 followed by your response.
# -----
# C  QNELSON ASKS WHERE MOST DO I GO IF IAM OPPRESS , FRINGLED ,INDIMITATED AND DEPRESSED OVER LAND CRAPPERS   REPORTED,   DOES THE CONSTITUTION  OFER ME FREE
# -----
# E A farmer asks: What can i give my hen to fatten early?And produce eggy early? Reply Q608 followed by your response.
# -----
# Martin asks: what is dibbling as used in crop production Reply Q1639 followed by your response.
#
# optout stop 6333
# -----
# Tumwebaze asks: what is the best type of tomatoes to plant that yields much fruits Reply Q75 followed by your response.
#
# optout stop 6333
# -----
# A farmer asks: Which herbecide i can use 2 spray my tomatoes? Reply Q258 followed by your response.
# -----
# MUSA asks: how many breeds of catle & which good to rearing s,western ug. Reply Q71 followed by your response.
#
# optout stop
# -----
# Tumwesigye asks: Whom can i contact,to sell mi yams. Reply Q72 followed by your response.
#
# optout stop 6333
# -----
# John asks: What type of sorghum is exported from Rwanda.
# -----
# Q gai hi swali n noma nagojea jibu Benjamin asks: Michael asks: What Causes A Hen To Hatch In 18 Days? Reply Q62.Hatching depends on how eggs have been handled,give a hen eggs layed 7 days (all layed in last week)
# -----
# Jagwenpa asks: Which disease attack cows by the cause ov ticks.
# -----
# Ambrose asks: What iz amaranthus specie?
# -----
# A farmer asks: What Causes Coffee Wilt Reply Q438 followed by your response.
#
# optout stop 6333
# -----
# A farmer asks: A,11, how can i help my cow if it was served and dint get pregnant? Reply Q188 followed by your response.
# -----
# Gilbert asks: which type of crop is suitable to be plant in kericho at this time? Reply Q15 followed by your response.
# -----
# James asks: QWhat causes black sooty stuff on maize tarsels Reply Q257 followed by your response.
# -----
# Q Ruth asks: we have a disease in our hen but attacked at de lungs,j would like to konw cause and de disease Reply Q97 followed by your response.
# -----
# What Meathed Dowe Use To Plant Egg Plant?Dennis Asks
# -----
# asks: which s te best tomatoes  1 plant at BOMET
# -----
# Molly asks: Ihave ahouse of hens only but it has hooping cough, what causes that hooping cough? Reply Q3239 followed by your response.
# -----
# Aisha asks: If I What to plant maize in octomber is it good? Reply Q1639 followed by your response.
#
# optout stop 6333
# -----
# Doreen asks What Are weeds ? Am cute girl 4rm mbarara am what is you r name mi dia.u Are 4rm where?. REPLY Q873 followed by your response.
# -----

# %% [markdown]
# ### Text Processing

# %%
# Import from local modules

def process_text(text: str) -> str:
    cleaned = clean_text(text)
    tokens = tokenize(cleaned)
    lemmas = lemmatize_tokens(tokens)
    return " ".join(lemmas)

questions['processed_text'] = questions['question_content'].apply(process_text)

# %% [markdown]
# ### Vectorization

# %%
# Use unigrams only since questions are short
vectorizer = TfidfVectorizer(
    max_features=5000,       # limit vocabulary size to reduce memory usage
    min_df=5,                # ignore words appearing in fewer than 5 questions
    max_df=0.7,              # ignore very common words
    ngram_range=(1,2)        # unigrams to bigrams
)

tfidf_matrix = vectorizer.fit_transform(questions['processed_text'])
print(tfidf_matrix.shape)  # (num_questions, 5000)
# Out:
# (100000, 5000)

# %%
n_components = 200  # start with 100 latent dimensions
svd = TruncatedSVD(n_components=n_components, random_state=42)
svd_matrix = svd.fit_transform(tfidf_matrix)

# %%
svd.explained_variance_ratio_.sum()
# Out:
# 0.3625956688759838

# %% [markdown]
# ### K-means Clustering

# %%
n_clusters = 10  # start with ~10 clusters, adjust after exploration
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
labels = kmeans.fit_predict(svd_matrix)

questions['cluster'] = labels

# %%
# Get the cluster centers in the reduced SVD space
centers = kmeans.cluster_centers_

# Project centers back to TF-IDF space to identify top words
# (This uses the SVD components to approximate the original feature space)
terms = vectorizer.get_feature_names_out()
components = svd.components_

for i in range(n_clusters):
    # approximate cluster center in original space
    center_tfidf = centers[i].dot(components)

    top_indices = center_tfidf.argsort()[::-1][:15]
    top_terms = [terms[idx] for idx in top_indices]

    print(f"\nCluster {i}:")
    print(", ".join(top_terms))
# Out:
# Cluster 0:
# hen, egg, lay, hen lay, lay egg, num_token, many, laying, give, many egg, layer, problem, hatch, cock, day
#
# Cluster 1:
# cow, milk, dairy, dairy cow, give, feed, best, problem, heat, num_token, cause, produce, sign, birth, cow produce
#
# Cluster 2:
# animal, cause, disease, feed, dairy, dairy animal, num_token, farm, use, best, give, animal feed, tick, like, production
#
# Cluster 3:
# one, many, acre, plant, chick, one acre, maize, num_token, much, old, young one, day, young, one best, get
#
# Cluster 4:
# season, plant, best, rainy, rainy season, dry season, plant season, dry, best season, maize, crop, planting, tomato, type, season plant
#
# Cluster 5:
# take, long, mature, long take, take mature, many, take long, month, day, many month, many day, ready, harvest, harvested, birth
#
# Cluster 6:
# maize, best, num_token, crop, get, tomato, use, type, bean, much, chicken, control, price, poultry, farm
#
# Cluster 7:
# buy, num_token, want, want buy, get, much, money, maize, num_token buy, buy maize, seed, chick, need, price, one
#
# Cluster 8:
# plant, maize, plant maize, best, banana, want, tomato, bean, num_token, seed, want plant, type, maize plant, plant tomato, good
#
# Cluster 9:
# grow, grow well, crop, crop grow, well, type, faster, maize, grow faster, num_token, want, take grow, best, want grow, grow tomato

# %%
# print sample questions from a cluster to manually inspect clustering / cleaning
samplecleaning = questions.loc[questions['cluster'] == 0, ['question_content','processed_text']].sample(30, random_state=42)
for a, q in samplecleaning.iterrows():
    print(a)
    print(q['question_content'])
    print(q['processed_text'])
    print("-"*80)
# Out:
# 160140
# Q how many eggs does a egg hen give a day. Not local ones
# q many egg egg hen give day local one
# --------------------------------------------------------------------------------
# 24987
# I   have   kienyegi  hens   i  have  feed  them  for  4months  but  their  havenot start  layers  eggs  what  is  the  problem,?
# kienyegi hen feed num_tokenmonths havenot start layer egg problem
# --------------------------------------------------------------------------------
# 620021
# : My hen has a problem hanging feathers as if imevaa koti medicine n gn
# hen problem hanging feather imevaa koti medicine n gn
# --------------------------------------------------------------------------------
# 684808
# Q. Which drug can be given to hens with swollen heads in apoultry house.
# q drug given hen swollen head apoultry house
# --------------------------------------------------------------------------------
# 75507
# Hens And Rabbits Which Is The Best To Keep
# hen rabbit best keep
# --------------------------------------------------------------------------------
# 791997
# Q:How did an old hen behave.!
# qhow old hen behave
# --------------------------------------------------------------------------------
# 118473
# l have thow hens they have coldness at every time what should l do?
# l thow hen coldness every time l
# --------------------------------------------------------------------------------
# 877304
# E WHY SOME LAYERS LAY EGGS WITHOUT YORK
# e layer lay egg without york
# --------------------------------------------------------------------------------
# 469484
# S. what does a hen that eat eggs lack?
# hen eat egg lack
# --------------------------------------------------------------------------------
# 303734
# Q what can be problem to my hen which does not lay eggs daily?
# q problem hen lay egg daily
# --------------------------------------------------------------------------------
# 492026
# HOW TO REAR HEN.
# rear hen
# --------------------------------------------------------------------------------
# 826286
# Q i intend to rare 20 hens how many cocks to i need to serve them well?.
# q intend rare num_token hen many cock need serve well
# --------------------------------------------------------------------------------
# 457925
# how many years does the hen takes to die
# many year hen take die
# --------------------------------------------------------------------------------
# 59652
# Q how many eggs can i give hen so that it can hatch well
# q many egg give hen hatch well
# --------------------------------------------------------------------------------
# 567514
# Which is the best type of Layers for eggs?
# best type layer egg
# --------------------------------------------------------------------------------
# 621767
# Q what are best balance diet for layers so as to lay more eggs
# q best balance diet layer lay egg
# --------------------------------------------------------------------------------
# 652946
# How many kilograms of maize flour do 20 hens take in aday?
# many kilogram maize flour num_token hen take aday
# --------------------------------------------------------------------------------
# 734301
# For how long does a hen take to hutch its layed eggs . Poultry farming.
# long hen take hutch layed egg poultry farming
# --------------------------------------------------------------------------------
# 538739
# If I want to incubate eggs what is the duration of the eggs for the hatching?
# want incubate egg duration egg hatching
# --------------------------------------------------------------------------------
# 642309
# What is the total number of eggs a hen has to lay in order to start hatching them into chicks
# total number egg hen lay order start hatching chick
# --------------------------------------------------------------------------------
# 755482
# Q my hens are passing out blood even sick wats da treatment
# q hen passing blood even sick wats da treatment
# --------------------------------------------------------------------------------
# 535245
# HOW DO YOU CARE EGGS IN AN INCUBATOR?
# care egg incubator
# --------------------------------------------------------------------------------
# 534568
# Q i deal in local birds(chicken) i do feed them on feeds to make them lay eggs but the numbers of eggs are still low what could be the cause?
# q deal local birdschicken feed feed make lay egg number egg still low could cause
# --------------------------------------------------------------------------------
# 202151
# How we adiseas attacks neck of hen flow forwad
# adiseas attack neck hen flow forwad
# --------------------------------------------------------------------------------
# 75813
# Where  I  can found hens for meat.
# found hen meat
# --------------------------------------------------------------------------------
# 56645
# Q Improve kienyeji lay eggs through or some time they stop leying' if some time stop laying they stop for how many days?
# q improve kienyeji lay egg time stop leying time stop laying stop many day
# --------------------------------------------------------------------------------
# 828531
# Q my hens cannot walk please help how can i do?
# q hen cannot walk please help
# --------------------------------------------------------------------------------
# 884118
# Q:How many kgs of layers shoul be feed to twenty hens per day.
# qhow many kg layer shoul feed twenty hen per day
# --------------------------------------------------------------------------------
# 478889
# How long is isthmus of the hen.
# long isthmus hen
# --------------------------------------------------------------------------------
# 511032
# Q, i want to keep hens how can i start
# q want keep hen start
# --------------------------------------------------------------------------------

# %%
# test k number
## Previously tested 5 to 20, the silhouette scores for all were terrible
k_values = range(5, 6) 

X = svd_matrix

# Store metrics
results = []

for k in k_values:
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = km.fit_predict(X)
    
    # Compute metrics
    sil_score = silhouette_score(X, labels)
    db_score = davies_bouldin_score(X, labels)  # X.toarray() needed for DB score
    
    results.append({
        "k": k,
        "silhouette": sil_score,
        "davies_bouldin": db_score
    })
    
    print(f"\n=== k = {k} ===")
    print(f"Silhouette: {sil_score:.4f}, Davies-Bouldin: {db_score:.4f}")
    

# Optional: put metrics into a DataFrame for easier plotting
metrics_df = pd.DataFrame(results)
print("\nSummary metrics per k:")
print(metrics_df)
# Out:
# === k = 5 ===
# Silhouette: 0.0083, Davies-Bouldin: 4.2739
#
# Summary metrics per k:
#    k  silhouette  davies_bouldin
# 0  5     0.00834          4.2739

# %% [markdown]
# ### HDBSCAN on TF-IDF + SVD

# %%
## Commented out HDBSCAN clustering to prevent long runtime
# hdb = HDBSCAN(min_cluster_size=15, metric='euclidean', cluster_selection_method='eom')
# hdb_labels = hdb.fit_predict(svd_matrix)

# %%
len(hdb_labels)
# Out:
# 100000

# %%
import pickle

# Save
with open('hdbscan_model.pkl', 'wb') as f:
    pickle.dump(hdb, f)

# %%
# Load tomorrow
with open('hdbscan_model.pkl', 'rb') as f:
    hdb = pickle.load(f)

# %%
import pandas as pd

df = pd.DataFrame({'cluster': hdb_labels})
print(df['cluster'].value_counts())
# Out:
# cluster
# -1      81715
#  379     2178
#  363      442
#  370      374
#  368      282
#         ...
#  143       15
#  106       15
#  76        15
#  192       15
#  49        15
# Name: count, Length: 382, dtype: int64

# %% [markdown]
# ### HDBSCAN on dense embeddings

# %%
# Apply separate cleaning function that just normalizes spacing and removes very common "Q" boilerplate
questions['Q_basic_clean'] = questions['question_content'].apply(minimal_clean)

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')  # smaller, faster for your dataset

texts = questions['Q_basic_clean'].tolist()
embeddings = model.encode(texts, batch_size=64, show_progress_bar=True)  # CPU batching
# Out:
# c:\Users\ruggb\.conda\envs\datakind\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\ruggb\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Batches: 100%|██████████| 1563/1563 [03:01<00:00,  8.60it/s]

# %%
# # UMAP (noise ratio 31.38% with 180 clusters)
# umap_model = umap.UMAP(
#     n_neighbors=30,      
#     n_components=5,      
#     metric='cosine',    
#     random_state=42
# )
# umap_embeddings = umap_model.fit_transform(embeddings)

# # HDBSCAN
# clusterer = HDBSCAN(
#     min_cluster_size=100,   
#     min_samples=10,       
#     metric='euclidean',   
#     cluster_selection_method='eom'  
# )

# cluster_labels = clusterer.fit_predict(umap_embeddings)
# questions['cluster'] = cluster_labels

# # Check proportion of observations in noise cluster (-1)
# noise_ratio = (cluster_labels == -1).mean()
# print(f"Noise ratio: {noise_ratio:.2%}")

# UMAP
umap_model = umap.UMAP(
    n_neighbors=60,      
    n_components=10,      
    metric='cosine',    
    random_state=42
)
umap_embeddings = umap_model.fit_transform(embeddings)

# HDBSCAN
clusterer = HDBSCAN(
    min_cluster_size=250,   
    min_samples=10,       
    metric='euclidean',   
    cluster_selection_method='eom'  
)

cluster_labels = clusterer.fit_predict(umap_embeddings)
questions['cluster'] = cluster_labels

# Check proportion of observations in noise cluster (-1)
noise_ratio = (cluster_labels == -1).mean()
print(f"Noise ratio: {noise_ratio:.2%}")
# Out:
# Noise ratio: 26.93%

# %%
len(pd.unique(questions['cluster']))
# Out:
# 65

# %%
# Filter out noise points
mask = cluster_labels != -1
embeddings_nonnoise = umap_embeddings[mask]
labels_nonnoise = cluster_labels[mask]

# Compute cluster coherence (mean pairwise cosine similarity per cluster)
cluster_ids = np.unique(labels_nonnoise)
cluster_coherence = {}

for cid in cluster_ids:
    idx = labels_nonnoise == cid
    cluster_emb = embeddings_nonnoise[idx]
    
    if cluster_emb.shape[0] == 1:
        cluster_coherence[cid] = 1.0
    else:
        sim_matrix = cosine_similarity(cluster_emb)
        n = sim_matrix.shape[0]
        upper_tri = sim_matrix[np.triu_indices(n, k=1)]
        cluster_coherence[cid] = upper_tri.mean()

# Convert to DataFrame
coherence_df = pd.DataFrame({
    'cluster': list(cluster_coherence.keys()),
    'coherence': list(cluster_coherence.values()),
    'size': [np.sum(labels_nonnoise == cid) for cid in cluster_ids]
}).sort_values('coherence', ascending=True)

# Prints least coherent clusters
print(coherence_df.head(10))

# weighted coherence
total_points = coherence_df['size'].sum()
weighted_coherence = (coherence_df['coherence'] * coherence_df['size']).sum() / total_points
print(f"Weighted dataset-level coherence: {weighted_coherence:.6f}")
# Out:
#     cluster  coherence   size
# 38       38   0.997099   9602
# 25       25   0.997287  12903
# 26       26   0.998470   5364
# 42       42   0.999130   1216
# 8         8   0.999146   3431
# 53       53   0.999201   1446
# 31       31   0.999286    588
# 5         5   0.999303   1866
# 2         2   0.999326   2570
# 27       27   0.999400   1546
# Weighted dataset-level coherence: 0.998775

# %%
top_n = 20  # number of clusters to inspect
examples_per_cluster = 5  # number of questions to show per cluster

# Get clusters sorted by size
cluster_counts = questions['cluster'].value_counts()
top_clusters = cluster_counts.head(top_n).index.tolist()

for cluster_id in top_clusters:
    print(f"\n--- Cluster {cluster_id} (size={cluster_counts[cluster_id]}) ---")
    cluster_questions = questions[questions['cluster'] == cluster_id]['Q_basic_clean'].head(examples_per_cluster)
    for q in cluster_questions:
        print("-", q)
# Out:
# --- Cluster -1 (size=26932) ---
# - What is the best soil to plant tobacco
# - who know the the market of cow peas and what is the cost of 1kg?
# - give me the difference btn sugar cane and maize?
# - what good animal saveif at hot area
# - CAN I GET MAIZE MARKET
#
# --- Cluster 25 (size=12903) ---
# - how can I do so as my birds can multiply faster as I use the traditional method ? Or is it advisable immediately after hatching I separate the chicks and mother?
# - Which disease for hens is characterized by crying eyes and wounds around the head
# - mr.Kameno keep chickens,without feather in the neck.How do you call,such chicken in vernacular?
# - I,ASK. my chicken needs to be'deworm which medicine did i. used
# - What Medicine A farmer should use to prevent newcatle disease in poultry
#
# --- Cluster 38 (size=9602) ---
# - which is the best option between buying either of this grade cows(not pedigrees):18month old heifer, mature heifer,incalf heifer or lactating dairy cow?
# - The best acaricide to spray cows is ALMATICKS
# - how many times can a gsd give birth to puppies in a year
# - Method of transpot livestock.
# - how long doe a cow takes to be pregnanted again
#
# --- Cluster 26 (size=5364) ---
# - HOW MENY TYPES OF MILET DO WE HAVE? ASK ME ABOUT TOMATO.
# - What causes kibotokwa in tomatos? and how to prevent or control it
# - How much will i sell onion @kg a crate of tomatoes around kisumu county
# - which is the best chemical to spray tomato when flowering?
# - Which type of tomato is best for growing
#
# --- Cluster 8 (size=3431) ---
# - I Know to plant banana plantation
# - There Was Abig Redish Banana Worm, It Affected The Banana Suckers So I What To Know What Brought It And How Can Be Prevented Because They Make The To Bananas Plant To Stard Unfirmly
# - What is the best variety of banana.
# - Banana Plants Take How Many Years Before Reducing In Production?
# - ask me .Q.I want to plant bananas .Which a the best way or method to use to plant and where can i get the seedlings
#
# --- Cluster 2 (size=2570) ---
# - how long does potatoes takes to be harvested?
# - at what season can i plant i rish potatoes?
# - which is the best time to plant potatoes in Nyeri?
# - ; How many sacks of potatoes can i harvest in an acre?
# - What is the appropriate ferterliser to top dress potatoes?
#
# --- Cluster 29 (size=2526) ---
# - A farmer asks: Whats is the use of pigs fichtes in our farm? Reply Q348 followed by your response. optout stop 6333
# - Where can i get a piglet of a good breed around jinja and at how much
# - E Do dogs eat piglets?
# - am rearing pigs but they are not growing fat yet i feed them well wat shud i do?
# - which disease can early attack pigs
#
# --- Cluster 5 (size=1866) ---
# - how can i space cabbage in the farm?
# - which cabbage variety does well in high altitude area
# - How long does cabbage take 2 mature
# - What the best soil for cabbage
# - How can we prevent cabbages and pumpkins from rotting during rain season
#
# --- Cluster 27 (size=1546) ---
# - Is their a market of this short rabbit
# - I Have Rabbits,there eyes crack sorround the eyes; is vaccine available?
# - What Is The Food Of raBbIT
# - i want to start keeping rabbit wat should i do??
# - MY RABBITS STAY ON THE FLOW CAN I CEMENT THE FLOW ?
#
# --- Cluster 12 (size=1528) ---
# - what is stack borer in coffee?
# - S ONE plant of coffee gives how many kgs per season.
# - u. what chemical(s) can I use to treat my coffee when coffee beans turn black on the cluster and drop, leafbuds or tops begin to dry and coffee borers ?
# - how is coffee planted
# - How often afarmer should spray coffee.
#
# --- Cluster 53 (size=1446) ---
# - what is propagation?
# - DURING PLANTING SESON THE RAIN CAN BE ON%OF HOW CAN I DO TO MANTAIN MY CROP .
# - .Can grow in lower part of murang'a county.that's along tana river.
# - What are the best high value crops that should be grown in greenhouses in kakamega county
# - Which Food z suitable 2 plant in dc rainy season
#
# --- Cluster 4 (size=1243) ---
# - METHOD ON WHO TO PLANT ONION
# - What time are the onion surposed to spend in a nursery bed
# - Where Can I Get Onions To Plant
# - What chemical can i use to sprey onions?
# - CROP _ONIONS _WHATS THE BEST INSECTICITE FOR WHITEMAGOTS IN ONIONS ?
#
# --- Cluster 42 (size=1216) ---
# - WHICH IS THE BEST SOIL OF FARMING
# - what is soil ph ?
# - What is land fragementation
# - if i be with a land how can i do to improve on fertility?
# - N, What is soil sample?
#
# --- Cluster 49 (size=1099) ---
# - outline major functions of a secretery in an agricultural organisation.
# - 0 WHAT ARE THE BENEFITS OF POULRY FARMING
# - RQ14 Wefarm help farmers to know there farm products and how to manage
# - ,why,is,agriculture,very,very,important,to,aman,?
# - what is your farm contain?
#
# --- Cluster 63 (size=1039) ---
# - Which Method Is Good To Plant Maize?
# - is this month good to plant maize n which type
# - which season that i can get a lot of maize?
# - how many days does a maize seed tak to gamenet
# - How Many Day Did Maize Plant Grow
#
# --- Cluster 44 (size=911) ---
# - Give any two types of beans?
# - Which are te appropriate boosters to use to increase yield of beans/n the correct preventive weedal medics
# - which month do we plant beans
# - how to i harvest beans
# - , How Can I Plant Beans
#
# --- Cluster 61 (size=886) ---
# - uestion: Which is the best maize variety to plant over this long rain season
# - Which is te best hybrid for maize is good 4 planting
# - is this weather sure for maize farm
# - Can I plants hybrid maize
# - ;Give 5 forms of hybrid vigour 2 crop plants
#
# --- Cluster 0 (size=874) ---
# - bees has migrated from two hives at ago, what may it be a reason?
# - Can i get the number of Emmanuel who is expert in beekeeping?
# - there are one queen in bee hive
# - HOW TO REAR BEES AND GROW GINGER
# - what are the causes of bees moving away from their hives.22301
#
# --- Cluster 47 (size=864) ---
# - Why packet flour is more expensive compared to those that has passed through poshomill direct?
# - HOW MUCH EACH KG OF MAIZE TODAYS PRICE?
# - What Is Da Price Of Beans, Banana, Maize, Soya Beans, An Rice.
# - : What is the price of maize in msk?
# - how much do maize cost in sembabule.
#
# --- Cluster 58 (size=855) ---
# - which habicide is good for spraying weeds in rice plant.
# - The ways in which crop rotation control weeds like potato act as a crop cover altanate with maize that is grass family: groundnut which is legume with millet.
# - if you have large tracts of land, which is the best method of weeding maize crop?
# - What is a weed killer?
# - how 2 handle weeds
#
# --- Cluster 32 (size=751) ---
# - A farmer Ask , Where Will I Sell My Grafted Avocado,
# - HOW CAN I TREAT MY AVOCADO FRUITS THAT ARE STAINED WITH BROWN BLISTERS?
# - ;why is it that when mangoes and ovacados frowering a boats?
# - hw can i plant oranges
# - Crops :its a season of harvest of mangoes ... MY Mango tree has no flowering ,what problem now?
#
# --- Cluster 19 (size=718) ---
# - I have ready sukuma wiki for in siaya. Connect me with the buyers
# - how many types of sukuma wiki do we have?
# - which is best fetalazer to put sukuma wiki after finishing two months after plantiog?
# - Please help me in my project,i want to plant sukuma wiki but i don't have seed.what can do to gate seed?
# - Can i plant sukuma wiki
#
# --- Cluster 52 (size=700) ---
# - Can i win today
# - Where is ashop wefarm in kiruhura
# - ;when is wfarm champion selection
# - how do someone do to join wefarm
# - n can i do my internship at wefarm
#
# --- Cluster 51 (size=689) ---
# - Now i dont have any poutry now which question am i going to reply
# - give me contact,am in kapchorwa, 0777389779
# - Whats your ful quiz
# - DO U HAVE CONTACT NUMBER,
# - IS THIS AGOOD WAY OF ANSWERING
#
# --- Cluster 37 (size=689) ---
# - how 2 make anursery beb
# - What is seedling plant?
# - which vegetables seeds plant on nursary bed
# - What is seed dormance?
# - what is thd difference betwin aseedbed and anursery bed22301
#
# --- Cluster 16 (size=678) ---
# - how to prepare land for planting watermelon
# - How long will it take for watermelon to grow? I want to plant an acre and what of the market?
# - I have watermelons ready on jan 20th where can i get readily market when ready?
# - would watermelon plant do well in elementaita nakuru county?
# - can i plant watermelon in a shamba where i harvested tomatoes
#
# --- Cluster 33 (size=662) ---
# - I have plantend passion fruits and us their bears fruits their have started daingup What is the problem
# - how can i space my passion fruit
# - is it good to mix salt n fungicide in one container for spraying passion fruit tree
# - What kind of fruits are marketable and they take small time to mature
# - what can i do to make good output of passion fruits?
#
# --- Cluster 60 (size=654) ---
# - How can l control maize stalk ?
# - My maize in shamba is affected with stalk borer. What can i do?
# - ten years ago maize plant was not affected with caterpillars like today what is the cause?
# - James asks: QWhat causes black sooty stuff on maize tarsels Reply Q257 followed by your response.
# - my maize it is oval,grey and thin lesions on the leaves.which type of disease and how i can controlled
#
# --- Cluster 34 (size=632) ---
# - Did the gov't assist the kenyan farmers by reducing the price of maize ?
# - , what is the main cash crop in kenya?
# - what type of nappier grass can do better in western part of kenya?
# - in which part of kenya is sunflower planted in large scale
# - but u guy how many Barracks are in uganda now if u know them mention?
#
# --- Cluster 24 (size=617) ---
# - How can I apply NPK or DAP on young and grown up Matoke?, I wish to know the importance of? NPK DAP. coffee?.
# - what are the negative effects of fertilizes to our farms ?
# - how do i know the best fertilizer
# - , which type of fertilizer is the best in acidic soil?
# - USESOF NITROGEN IN PLANTS
#
# --- Cluster 13 (size=588) ---
# - What stage should tea be cut?
# - Iam tea farmer clon TN so how can i get terget of 2.5kg per year.
# - whats the cause of Amillaria root rot in the tea farm?
# - what plants can i grow in tea zone apart from tea?
# - Does Clone 303 Type Of Tea Suiting /grown In Bomet Areas Of Tea
#
# --- Cluster 31 (size=588) ---
# - is neppier grass good for milking animal
# - Give me 5 steps of making hay.
# - #Nappier is the best.
# - which pastures is the best between napier grass and former roads
# - ,where Should I Put Preventition Like Tree And Napier Grass In Top Or Slope?
#
# --- Cluster 30 (size=571) ---
# - How wil u know a duck is on heat?
# - Animals. My cow produced acalf ,how long acalf will it also go on heat?
# - what are the sighns of heat in a cow?
# - S what is the best cow heat timing (hour)that can't fail AI
# - Why do my male pig doesn't its fellow pigs yet dey are on heat.
#
# --- Cluster 62 (size=557) ---
# - Which parts of a maize is there purposeless.?
# - WHICH COUNTRY WAS THE FIRST TO PLANT MAIZE?
# - What type of maize is good to plant this season??
# - Which maize is well to plant in short season
# - Which Type Of Maize Is Able 2give Me Best Harvestation Thanks.Am Mbaga Nicholus From Kyegegwa 0777003661
#
# --- Cluster 28 (size=554) ---
# - How can I help my maize plant which is being destroyed by armyworm
# - is there any chemical which controls cut worms in watermelon shamba? Am realy servering help me plz give an advice
# - Which is the best eradication of fallarmyworm
# - in Nakuru to avoid this fowl army worm during season of planting maize, which is the best way to avoid them
# - WHAT DO WE USE TO CONTROL FOWL ARMYWORMS THAT ATTACK MAIZE
#
# --- Cluster 9 (size=547) ---
# - hw can u care 4 cassava
# - How do i get that cassava which matures in six months am in jinja
# - what is the best space in meters that should be used when planting cassava?
# - what is the best type crop crop 2 grow in cassava
# - How l can avoid cassava mosaic?
#
# --- Cluster 17 (size=520) ---
# - can i plant groundnuts and sweet potatoes on cotton soil can it be productive
# - how long does ground nuts take to be harvested how can it be harvested
# - can a person top dress groundnuts?
# - n.How can i control stunted growth of ground nuts?
# - Hw long does g/nuts take to mature/harvested
#
# --- Cluster 1 (size=509) ---
# - How Is Fish Beneficial To Our Economy And As Individuals
# - Can we digitalise fishing.....
# - Which type of fish feeds should be given when the're 1-2 months old?
# - WHAT SHOULD IDO WHEN INEED TO DUG THE DAM OV FISH?
# - Does fish should be givnn foods daily? and how much of it should feed 1000 fish? (0726058943)
#
# --- Cluster 6 (size=503) ---
# - how many days does a carrot take to germinate?
# - and what about planting dhania and carrots
# - I would like to plant carrots which seed variaty is best and where will gethem?
# - I want to try planting carrot on the same land i plant onions is it advisable and how do I do it I have never done that.
# - Best carrot seeds
#
# --- Cluster 15 (size=502) ---
# - at which intevals do we plant water melon and how?
# - Do water melon seeds do well when removed from afresh water melon then planted?
# - How do ants affect water melon?
# - S:which type of fertilizer is best for planting water melons?
# - what are some of the varieties of water melon and hw many types do water melon have name them 4 me!
#
# --- Cluster 14 (size=502) ---
# - what is the use of sugarcane in human beings?
# - What can i do for the sugarcanes that are yellowish yet there is no weed in the plantation?
# - as people of western kenya we like sugarcane plantation can i mix with maize and if no why thanks
# - WHAT IS THE BEST FERTILIZER FOR SUGAR CANE
# - what are the disadvantages of planting sugarcane
#
# --- Cluster 40 (size=456) ---
# - how many types ov trees are used 4 electric poles and can b best grown in northern uganda?
# - which best type of tree can i grow and give me the first output?
# - ,Can eucalyptus trees affect the growth and quality|quantity of maize crops grown on the same farm?
# - Beatrice asks: How Can One Determine The Age Of A Tree Plant? Reply Q816 followed by your response.
# - #what are the uses of bamboo tree
#
# --- Cluster 45 (size=443) ---
# - , Wht Iz Da Cost Ov 1 Kg Of Beans
# - Hi Wefarm:wats The Market Price Of One Heep Of Mullele Bean Leaves In Nakasero Market?
# - I have french beans, where to i get market?what is the cost per kilo?
# - .any market for beans
# - What is the cost of akilograme of beanr.
#
# --- Cluster 10 (size=440) ---
# - ma cow have given birth 3 wks ago, what,s tha best salt 4 it 2 use
# - which type of salt is given to the cow so that it comes on heat?
# - Which Is The Best Salt For For Animal Lossing Fur
# - Macklic super and Afya Bora salt which one has high mineral value milking cows.
# - -What time is good for me to give salt to my cow, is't after milking or before?
#
# --- Cluster 7 (size=422) ---
# - Jagwenpa asks: Which disease attack cows by the cause ov ticks.
# - How can we prevent ticks?
# - How can i control ticks without using pesticides?
# - How can i control ticks in dairy animals?
# - ,may i know the best method of preventing ticks in a cattle farm?
#
# --- Cluster 23 (size=419) ---
# - how many times should I give my maize fertilizer and which type of fertilizer
# - #Q: At what stage do I need to topdress my Maize farm and which fertilizer are suitable
# - What are the most used fertilizer when planting maize
# - What Is The Recomended Fertilizers To Use When I Want To Increase Maize And Beans Production?
# - can foliar fertilizer be used in maize if it can how many times
#
# --- Cluster 41 (size=417) ---
# - How many sacks of maize will a farmer harvest in one acre?
# - HW MANY FTS DAT MAKE 2 YARDS
# - how many half inch horsepipes can i use to irrigate with in a Quarter acre piece of land
# - If you have plant half acre how many bags will be harvested of maize
# - Hi wesley ask; if you plant some maize like 2kg of Dk 77.how many kg of fertilizer to we have.Q63.
#
# --- Cluster 3 (size=394) ---
# - My egg plants are wilting at an early flowering stage one crop by one. Rain z present, i spray and i spaced very well. U think wat z da ca
# - What Meathed Dowe Use To Plant Egg Plant?Dennis Asks
# - How to plant egg plant?
# - HOw To Plant Eggtplants
# - which medicen can i use to watering my egg plant
#
# --- Cluster 48 (size=389) ---
# - I plant amaize some part turn yellow what is the problem.
# - My crops are growing wz yellow leaves wat can do
# - When i plant maize it reach 1month da leaves become yellowish what cause that colour
# - what causes withering and Colour purple in maize
# - how do you control rice from yellowish
#
# --- Cluster 50 (size=385) ---
# - what are disadvangages of mono cropping in crop production
# - Which method can we use to encourage farmers to embrance agro forestry
# - WAT ARE BENEFITS OF AGRO FORESTRY.
# - Define pomoculture?
# - why people lyke agricuiture.
#
# --- Cluster 39 (size=382) ---
# - HOW CAN I CARE FOR MAI PUPPIES?
# - reason of keeping animals health
# - which animal is the best to keep
# - how many animals type hav GIGGERS?
# - What Is Inbreeding?
#
# --- Cluster 18 (size=377) ---
# - how do i plant spinach
# - ,HOW CAN I PLANT KALE SEEDS ON A SEED BED
# - HOW MANY CM DEEP SHOULD I DIG FOR A KALE
# - Which is the best fertilizer for kales?
# - ask how long spinach stay in bed:
#
# --- Cluster 54 (size=374) ---
# - What s the different asexual and sexual in plants
# - where can i get miraa plants?
# - What Is Floweringplant In Flowers
# - Should we start planting am shivan 4rom kashare kashari
# - HW 2 PLANT MAIZ
#
# --- Cluster 56 (size=364) ---
# - PAUL wanted to know is it adevisable to plant maize together with soyabean in one gaden
# - Elo wefarm members there z a farmer who wanted to cut coffee to plant maize hw would u advice him.
# - the farm is small scale so can i plant them togther maize,beans an peas or can i put dffrnt line
# - is it right to plant maize and beans in the same hole?
# - Which Type Of Beans Can Be Planted Together With Maize
#
# --- Cluster 36 (size=357) ---
# - MMASI ASKS;HOW CAN I SPACE,WHEN PLANTING MAIZE?
# - what is the appropriate spacing for maize while planting
# - Of which distance am I spoused to leave when am planting maize
# - What is the best spacing for maize?
# - why is not better to plant 2grops in one hole at the same time?
#
# --- Cluster 11 (size=340) ---
# - how to plant rice
# - How can you plant the rice. Give me method of planting rice.
# - What tool is mostly used when planting rice?
# - how can some one prepare a garden to plant rice
# - WHAT TYPE OF SOIL IS GOOD FOR RICE GROWING
#
# --- Cluster 21 (size=315) ---
# - are plant leaves enough to mek a compost manure without any animal waste
# - how can i make organic manure and the materials used?
# - Which Type Ov Manure Can I Apply On Maize Wen Is At Three Leaves.
# - What is vermicompost? different between compost manure and vermicompost
# - WHAT.ARE.THE.PREPARATION.OF.FARMYARD.MANURE?MY.CROP.IS.WHEAT.
#
# --- Cluster 43 (size=309) ---
# - cross cocoo beans turn leave colour 2yellowish yet have 3wks since planted.why? and which chemical is used? .Remember we have wefarm draw of 10000 this weekend,if you answer it well you stand a chance of winning!
# - My beans have some small holes on the leaves, what can I use?
# - Iam a small scale farmer,have beans at flowering stage some turning yellow what's the problem?
# - what causes whall on leaves of bean seed?
# - My beans have got yellow leaves,what can i apply?
#
# --- Cluster 22 (size=307) ---
# - which is the right time for top dressing?
# - At Which height do i topdress maize
# - which Fertilizer Is Best Top Dressing Maize Crop
# - G 2 farmer abt crops.which type of top dressing fertilizer is good 4 maize.
# - Can a farmer top dress maize at flowering stage. ?
#
# --- Cluster 59 (size=303) ---
# - My beans have been infected by some black flies. What do i use to get rid of them?
# - # my beans is about to flower is it adviceable to apply sulphate
# - Beans farming pest and pesticides to use
# - which types of medicine i used for spraying beans for more yield?
# - What is the best method of controlling pests and diseases on beans?
#
# --- Cluster 55 (size=295) ---
# - What are of the storage pests attacking stored millet?
# - what are pests
# - mi crops now are attacked by pests & dieases wat am i going 2 do ?
# - How can i make local pestcides 2 chase away pests on crops?
# - ways ov controlling crop pests.
#
# --- Cluster 35 (size=280) ---
# - My sheep have mucus with blood whats the medicine
# - My cow has started to develop blindness and it's about to give birth help me what should I do or use
# - ,why Are Some Sheep ''sneeze''with Alot Of Mucus?
# - ,Wht cld be the problem my father's goat cough's?
# - MY COW IS SNISSING&COUGHING WHAT DO I DO?
#
# --- Cluster 46 (size=278) ---
# - what could be the of Price of 1kg of been in Kampala?
# - What.is.the.price.of.maze.per.kg?
# - n what's the current price of coffee and maize in Eastern Uganda (Busoga)?.
# - Pleas help i wuold like to know the price of incubatar plz
# - what is the price of rocket and stricker ?
#
# --- Cluster 57 (size=262) ---
# - What can i use to spray maize to prevent kattapillers
# - what was best pestcide to use to control armywarm i us bold but the warm are continuing destroying my maize
# - Which chemical should i use to spray my maize when it is still 3weeks young
# - Joshua asks: What medicine is used to spray on maize to kill pests that destroy the leaves Reply Q1005 followed by your response. optout stop 6333
# - J want to spray my maize ,what pesticide can j use?
#
# --- Cluster 20 (size=260) ---
# - S which type of sorghum would i plant in this season?
# - A farmer asks: Am planing 2grow millet in a swampy area. How can i grow it Reply Q571 followed by your response.
# - John asks: What type of sorghum is exported from Rwanda.
# - hw lng does it took millet to grow
# - HOW TO FARM SORGUM
