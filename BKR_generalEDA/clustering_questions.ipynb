# %%
import pandas as pd
from dotenv import load_dotenv
import os
import duckdb
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import silhouette_score
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')
nltk.download('stopwords')


load_dotenv()
# Path for 1 million English sample questions
sample_path = os.getenv("DATA_SAMPLE")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ruggb\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ruggb\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Clustering on question content (English)

# %%
dataset = pd.read_parquet(sample_path)

# Drop duplicate questions
questions_raw = dataset.drop_duplicates(subset='question_content', keep='first')

# Random sample of rows, reproducible with random_state
questions = questions_raw.sample(n=100000, random_state=42)

# %% [markdown]
# ### Text Processing

# %%
# Cleans common starting formatting for questions
def strip_prefixes(text):
    text = text.lower()  # lowercase for consistent matching

    # Remove leading numeric IDs
    text = re.sub(r'^\s*\d+\s+', '', text)

    # Remove multiple nested "Name asks:" or "A farmer asks:" patterns
    # This removes repeated patterns at the start of the string
    pattern_asks = re.compile(r'^(?:[a-z\s]+ asks:)+\s*', flags=re.IGNORECASE)
    text = pattern_asks.sub('', text)

    # Remove Q, Qn, Qn:, Q:, Q followed immediately by a word (like Qwhat)
    text = re.sub(r'^q[n]?\s*[:,-]?\s*', '', text)
    text = re.sub(r'^q(?=[a-z])', '', text)  # removes Q directly followed by a word

    # Remove "Reply Q", "Reply Qn", "Reply followed" boilerplate
    text = re.sub(r'^reply\s+q[n]?\s*[:,-]?\s*', '', text)
    text = re.sub(r'^reply\s+followed\s*', '', text)

    # Remove any remaining leading/trailing whitespace
    text = text.strip()

    return text

def clean_text(text):
    # run prefix stripper FIRST
    text = strip_prefixes(text)

    text = text.lower()  # lowercase
    text = re.sub(r'\d+', '', text)  # remove numbers
    text = re.sub(r'[^\w\s]', '', text)  # remove punctuation
    text = re.sub(r'\bq\b', '', text) # removes starting 'q' for questions
    text = re.sub(r'\s+', ' ', text).strip()  # remove extra whitespace
    return text

questions['cleaned_text'] = questions['question_content'].apply(clean_text)

# %%
# Remove stop words and tokenize
stop_words = set(stopwords.words('english'))

def tokenize(text):
    return [word for word in text.split() if word not in stop_words]

questions['tokens'] = questions['cleaned_text'].apply(tokenize)

# %%
lemmatizer = WordNetLemmatizer()

def lemmatize_tokens(tokens):
    return [lemmatizer.lemmatize(token) for token in tokens]

questions['tokens'] = questions['tokens'].apply(lemmatize_tokens)

# %%
questions['processed_text'] = questions['tokens'].apply(lambda tokens: ' '.join(tokens))

# %% [markdown]
# ### Vectorization

# %%
# Use unigrams only since questions are short
vectorizer = TfidfVectorizer(
    max_features=5000,       # limit vocabulary size to reduce memory usage
    min_df=5,                # ignore words appearing in fewer than 5 questions
    max_df=0.7,              # ignore very common words
    ngram_range=(1,1)        # unigrams
)

tfidf_matrix = vectorizer.fit_transform(questions['processed_text'])
print(tfidf_matrix.shape)  # (num_questions, 5000)
# Out:
# (100000, 5000)

# %%
from sklearn.decomposition import TruncatedSVD

n_components = 100  # start with 100 latent dimensions
svd = TruncatedSVD(n_components=n_components, random_state=42)
svd_matrix = svd.fit_transform(tfidf_matrix)

print(svd_matrix.shape)  # (num_questions, 100)
# Out:
# (100000, 100)

# %%
import numpy as np

terms = np.array(vectorizer.get_feature_names_out())
for i, comp in enumerate(svd.components_):
    top_terms = terms[np.argsort(comp)[-10:]]  # top 10 words for this component
    print(f"Component {i}: {', '.join(top_terms)}")
# Out:
# Component 0: crop, good, season, seed, bean, tomato, type, best, maize, plant
# Component 1: hole, right, rain, iwant, want, bean, carrot, season, banana, plant
# Component 2: control, much, kg, fertilizer, seed, bean, planting, best, price, maize
# Component 3: way, breed, planting, variety, soil, season, crop, type, tomato, best
# Component 4: followed, reply, want, good, feed, dairy, plant, milk, get, cow
# Component 5: bean, get, good, use, response, followed, type, reply, tomato, crop
# Component 6: maize, response, followed, reply, long, take, grow, type, cow, crop
# Component 7: bean, cause, control, use, optout, stop, best, response, followed, reply
# Component 8: response, followed, chick, reply, bean, seed, market, best, crop, get
# Component 9: price, many, soya, good, fertilizer, planting, banana, use, type, bean
# Component 10: many, stop, optout, maize, seed, good, response, followed, reply, type
# Component 11: followed, reply, good, milk, season, price, crop, tomato, cow, bean
# Component 12: cow, control, seed, long, good, use, planting, plantation, get, banana
# Component 13: hw, wilt, one, tomato, plantation, kg, many, price, much, banana
# Component 14: kg, acre, crop, fertilizer, month, day, potato, one, use, many
# Component 15: potato, fertilizer, time, start, many, egg, hen, season, planting, good
# Component 16: farm, need, kg, poultry, use, potato, farming, start, want, much
# Component 17: month, control, bean, farming, want, start, farm, seed, poultry, many
# Component 18: type, know, lay, banana, want, cow, price, seed, egg, hen
# Component 19: kg, farm, good, animal, potato, cause, disease, control, seed, much
# Component 20: much, give, want, feed, banana, use, bean, chick, grow, seed
# Component 21: want, cabbage, disease, pig, animal, grow, cause, price, potato, seed
# Component 22: dairy, farm, use, goat, breed, seed, control, many, price, good
# Component 23: well, farm, want, good, pig, hen, soil, potato, control, grow
# Component 24: old, one, give, cow, potato, season, seed, price, control, chick
# Component 25: cabbage, rainy, many, grow, control, dry, pig, disease, chicken, season
# Component 26: tomato, irish, bean, sweet, farming, good, banana, poultry, potato, chicken
# Component 27: pig, rabbit, crop, give, control, know, disease, planting, want, chicken
# Component 28: onion, cow, many, coffee, good, cause, grow, chicken, soil, cabbage
# Component 29: poultry, animal, seed, price, planting, chicken, feed, soil, pig, farm
# Component 30: milk, production, know, season, goat, dairy, want, farm, chicken, animal
# Component 31: breed, growing, know, use, one, cause, goat, want, season, soil
# Component 32: weed, type, chick, good, know, cabbage, want, pig, cause, farm
# Component 33: disease, rabbit, grow, breed, milk, chicken, goat, give, one, farm
# Component 34: feed, farming, milk, cattle, cabbage, planting, cause, dairy, control, goat
# Component 35: season, control, soil, feed, animal, market, rabbit, farming, cabbage, one
# Component 36: onion, type, fertilizer, long, cow, coffee, grow, disease, pig, one
# Component 37: affect, season, pig, dairy, goat, farm, soil, feed, disease, cabbage
# Component 38: cause, disease, seed, planting, dairy, goat, farm, market, feed, rabbit
# Component 39: spray, know, farming, tree, farmer, used, give, feed, fertilizer, coffee
# Component 40: want, milk, hw, feed, farmer, goat, would, like, know, poultry
# Component 41: need, chemical, chick, rabbit, spray, goat, like, know, used, time
# Component 42: farmer, rabbit, coffee, fertilizer, improve, chick, produce, breed, production, milk
# Component 43: market, season, used, apply, need, know, onion, goat, month, fertilizer
# Component 44: soil, season, wat, poultry, chemical, spray, fertilizer, want, used, time
# Component 45: onion, season, need, cattle, use, control, wefarm, fertilizer, farmer, time
# Component 46: livestock, production, fruit, cattle, spray, milk, chemical, used, market, onion
# Component 47: produce, animal, onion, variety, start, milk, goat, coffee, time, market
# Component 48: cow, problem, used, wefarm, want, month, goat, wat, market, farmer
# Component 49: feed, like, milk, start, get, iz, need, variety, onion, wat
# Component 50: farm, give, passion, dairy, farming, know, fruit, cattle, wat, market
# Component 51: produce, livestock, time, like, production, start, passion, fruit, milk, month
# Component 52: farming, market, dairy, wat, breed, cattle, time, onion, coffee, month
# Component 53: medicine, keeping, month, hen, market, hw, breed, start, need, cattle
# Component 54: want, cause, best, goat, market, improve, prevent, farming, onion, hw
# Component 55: want, hw, problem, onion, time, breed, passion, month, fruit, whats
# Component 56: dairy, give, spray, start, lay, breed, passion, onion, fruit, egg
# Component 57: lay, spray, melon, time, hw, cattle, water, month, egg, variety
# Component 58: onion, hw, wefarm, livestock, egg, spacing, need, melon, whats, water
# Component 59: market, wefarm, would, variety, like, keeping, livestock, cattle, start, whats
# Component 60: want, month, production, food, dairy, variety, medicine, cattle, whats, need
# Component 61: improve, area, well, farming, method, sheep, need, feed, breed, livestock
# Component 62: goat, day, egg, feed, spray, sheep, wefarm, farming, cattle, medicine
# Component 63: market, cassava, milk, day, spray, produce, breed, chemical, whats, wefarm
# Component 64: make, keeping, used, help, way, dairy, prevent, method, livestock, wefarm
# Component 65: tree, well, prevent, method, cattle, produce, area, dry, leaf, make
# Component 66: heat, fruit, sign, much, weed, way, prevent, method, cattle, day
# Component 67: make, heat, area, sign, day, chemical, cattle, livestock, spray, food
# Component 68: yellow, dry, much, pest, medicine, dairy, make, leaf, livestock, day
# Component 69: period, production, problem, weed, chemical, pest, spray, kg, way, prevent
# Component 70: name, spray, leaf, livestock, breed, make, prevent, variety, food, pest
# Component 71: spacing, much, mango, day, improve, production, food, pest, planted, tree
# Component 72: improve, sign, chemical, grass, plantation, variety, spacing, tree, weed, make
# Component 73: county, spacing, well, garden, breed, livestock, medicine, food, weed, prevent
# Component 74: livestock, make, keep, way, tree, spray, produce, well, spacing, pest
# Component 75: period, much, way, many, cassava, spacing, production, area, improve, dry
# Component 76: month, way, calf, cost, dry, make, pest, day, kg, spacing
# Component 77: grass, help, like, could, watermelon, leaf, planted, keep, problem, spacing
# Component 78: gestation, control, milk, well, chemical, know, period, leaf, spacing, prevent
# Component 79: period, suitable, want, land, county, prevent, make, would, growing, like
# Component 80: harvest, production, carrot, gestation, way, make, well, period, county, planted
# Component 81: help, milk, grass, growing, livestock, chemical, pest, sheep, gestation, period
# Component 82: milk, grass, period, like, keeping, bee, dry, spray, planted, method
# Component 83: heat, production, sign, carrot, suitable, spray, weed, pest, growing, method
# Component 84: heat, help, calf, livestock, make, chemical, grass, sign, area, planted
# Component 85: know, milk, planted, used, suitable, sheep, spray, grass, way, growing
# Component 86: dry, goat, cattle, leaf, cassava, chemical, grass, name, county, keep
# Component 87: improve, keeping, napier, problem, plantation, cassava, help, well, name, grass
# Component 88: chemical, make, problem, production, bee, county, name, land, calf, sheep
# Component 89: carrot, watermelon, suitable, tea, way, growing, planted, produce, improve, name
# Component 90: dry, county, suitable, manure, cassava, wiki, land, sukuma, cost, plantation
# Component 91: cassava, tea, county, given, help, cost, rice, plantation, sheep, name
# Component 92: cassava, acre, calf, watermelon, day, wiki, keep, sukuma, land, name
# Component 93: county, produce, heat, grass, calf, cost, sign, wiki, sukuma, help
# Component 94: planted, growing, keeping, well, name, heat, grass, sign, bee, carrot
# Component 95: keep, kg, day, sheep, carrot, garden, chemical, county, suitable, help
# Component 96: garden, growing, milk, watermelon, dry, cassava, help, harvest, layer, cost
# Component 97: production, apply, sheep, chemical, mature, dry, way, method, wiki, sukuma
# Component 98: rice, problem, bed, harvest, county, chemical, suitable, tea, way, carrot
# Component 99: suitable, help, area, layer, problem, carrot, keep, mature, cost, watermelon

# %%
svd.explained_variance_ratio_.sum()
# Out:
# 0.34433005617053897

# %%
from sklearn.cluster import KMeans

n_clusters = 10  # start with ~10 clusters, adjust after exploration
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
labels = kmeans.fit_predict(svd_matrix)

questions['cluster'] = labels

# %%
import numpy as np

# Get the cluster centers in the reduced SVD space
centers = kmeans.cluster_centers_

# Project centers back to TF-IDF space to identify top words
# (This uses the SVD components to approximate the original feature space)
terms = vectorizer.get_feature_names_out()
components = svd.components_

for i in range(n_clusters):
    # approximate cluster center in original space
    center_tfidf = centers[i].dot(components)

    top_indices = center_tfidf.argsort()[::-1][:15]
    top_terms = [terms[idx] for idx in top_indices]

    print(f"\nCluster {i}:")
    print(", ".join(top_terms))
# Out:
# Cluster 0:
# hen, egg, lay, many, laying, chicken, give, layer, day, eat, take, hatch, kienyeji, eating, long
#
# Cluster 1:
# plant, maize, bean, tomato, want, season, type, good, seed, crop, potato, use, many, time, cabbage
#
# Cluster 2:
# banana, plantation, plant, wilt, bacteria, planting, control, use, type, best, good, disease, leaf, many, spacing
#
# Cluster 3:
# best, plant, maize, type, variety, planting, season, tomato, seed, way, fertilizer, crop, breed, bean, soil
#
# Cluster 4:
# much, kg, cost, maize, hw, per, one, bean, money, get, kilo, tomato, chick, kilogram, need
#
# Cluster 5:
# cow, milk, dairy, give, feed, heat, best, problem, produce, cause, birth, sign, many, salt, pregnant
#
# Cluster 6:
# crop, tomato, get, use, take, type, long, bean, animal, chicken, chick, many, good, pig, grow
#
# Cluster 7:
# reply, followed, response, optout, stop, plant, maize, best, cow, use, crop, bean, tomato, type, asks
#
# Cluster 8:
# maize, price, planting, seed, bean, type, use, control, good, farm, many, crop, fertilizer, grow, pest
#
# Cluster 9:
# poultry, start, farming, keeping, farm, disease, bird, house, keep, want, cause, control, egg, need, farmer

# %%
questions.loc[questions['cluster'] == 7, 'question_content'].sample(30, random_state=42)
# Out:
# 616256    Emma asks: pliz guyz is anyone with an idea on...
# 681152    Vincent asks: Does cabbages require any sprayi...
# 259659    Charles asks: How many varieties of banana so ...
# 919146    Stephen asks: Ama asks: what is the gestation ...
# 347713    A farmer asks: sugest a reason why i prefer to...
# 166604    Shamim asks: So how many meters shd be use whe...
# 594161    Q Aggrey asks: How comes that Gulu land does n...
# 84518     Josephine asks: What is the spacing of plantin...
# 866718    Nicholas asks: A farmer asks: What is the diff...
# 88892     Shivan asks: WHAT SHOULD I DO? ALL MY HENS&COC...
# 892303    A farmer asks: How many varieties of rabbits d...
# 433146    Q A farmer asks: Bt Hw Many Kg Can On One Hole...
# 237085    A farmer asks: what do we call the female shee...
# 833786    Pamela asks: can i get loan. Reply Q326 follow...
# 979736    Q which is the best medicine of chickens that ...
# 36965     Joel asks: my cabbeges r about 2 b ready bt le...
# 393370    Mary asks: What is aspergillassis in chicken? ...
# 241847    Wilson asks: What Is Live Stock Reply Q75 foll...
# 338058    A farmer asks: I want 2 kill weeds not pests i...
# 717060    Paul asks: Suitable Condition For Keeping Beef...
# 515133                                      WHAT OF REPLY ?
# 62810     Gilbert asks: how best can i improve on animal...
# 994153    Joshua asks: What is the cost of a 25 kg sack ...
# 777550    Tugume asks: Botanical name of banana weavil R...
# 458090    Ruth asks: Can.l.get.d.ap.for.laon? Reply Q263...
# 654305    Spencer asks: i want to plant tomatose what ar...
# 439640    Wycliffe asks: Why is milk important for chick...
# 276779    Kato asks: Bosco asks: What is the spacing for...
# 776966    Rehema asks: for the case of maize,most maize ...
# 321967    Brian asks: Where can get the seeds of sukuma ...
# Name: question_content, dtype: object

# %%
# junk_terms = ["reply", "followed", "optout", "stop"]
junk_terms = ["Dady Wa Penny"]
mask = questions['question_content'].str.contains(
    '|'.join(junk_terms),
    case=False,
    na=False
)

junk_subset = questions[mask]
print(junk_subset.shape)
# Out:
# (2, 28)

# %%
for a in junk_subset['question_content']:
    print(a)
# Out:
# Dady Wa Penny asks: Hello wefarm,which type of plant can a poor man deep in the village plant on ahalf an acre and it can give good harvest and some mone
# Dady Wa Penny asks: my calf dificat blood what causes that. Gd 9t Reply Q471 followed by your response.
#
# optout stop 6333

# %%
for question in junk_subset.sample(30, random_state=42)['question_content']:
    print(question)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 for question in junk_subset.sample(30, random_state=42)['question_content']:
#       2     print(question)
#
# File c:\Users\ruggb\.conda\envs\datakind\lib\site-packages\pandas\core\generic.py:6118, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    6115 if weights is not None:
#    6116     weights = sample.preprocess_weights(self, weights, axis)
# -> 6118 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    6119 result = self.take(sampled_indices, axis=axis)
#    6121 if ignore_index:
#
# File c:\Users\ruggb\.conda\envs\datakind\lib\site-packages\pandas\core\sample.py:152, in sample(obj_len, size, replace, weights, random_state)
#     149     else:
#     150         raise ValueError("Invalid weights: weights sum to zero")
# --> 152 return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     153     np.intp, copy=False
#     154 )
#
# File numpy\\random\\mtrand.pyx:1001, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'
