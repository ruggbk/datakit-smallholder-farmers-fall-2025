# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import silhouette_score
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ruggb\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ruggb\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # Clustering on question content (English)

# %%
dataset = pd.read_csv('data/farmers_1mil_eng_sample.csv', index_col = 0)
# Drop duplicates for questions
questions_raw = dataset.drop_duplicates(subset='question_content', keep='first')

# %%
# Random sample of rows, reproducible with random_state
questions = questions_raw.sample(n=100000, random_state=42)

# %% [markdown]
# ### Text Processing

# %%
# Cleans common starting formatting for questions
def strip_prefixes(text):
    text = text.lower()  # lowercase for consistent matching

    # Remove leading numeric IDs
    text = re.sub(r'^\s*\d+\s+', '', text)

    # Remove multiple nested "Name asks:" or "A farmer asks:" patterns
    # This removes repeated patterns at the start of the string
    pattern_asks = re.compile(r'^(?:[a-z\s]+ asks:)+\s*', flags=re.IGNORECASE)
    text = pattern_asks.sub('', text)

    # Remove Q, Qn, Qn:, Q:, Q followed immediately by a word (like Qwhat)
    text = re.sub(r'^q[n]?\s*[:,-]?\s*', '', text)
    text = re.sub(r'^q(?=[a-z])', '', text)  # removes Q directly followed by a word

    # Remove "Reply Q", "Reply Qn", "Reply followed" boilerplate
    text = re.sub(r'^reply\s+q[n]?\s*[:,-]?\s*', '', text)
    text = re.sub(r'^reply\s+followed\s*', '', text)

    # Remove any remaining leading/trailing whitespace
    text = text.strip()

    return text

def clean_text(text):
    # run prefix stripper FIRST
    text = strip_prefixes(text)

    text = text.lower()  # lowercase
    text = re.sub(r'\d+', '', text)  # remove numbers
    text = re.sub(r'[^\w\s]', '', text)  # remove punctuation
    text = re.sub(r'\bq\b', '', text) # removes starting 'q' for questions
    text = re.sub(r'\s+', ' ', text).strip()  # remove extra whitespace
    return text

questions['cleaned_text'] = questions['question_content'].apply(clean_text)

# %%
# Remove stop words and tokenize
stop_words = set(stopwords.words('english'))

def tokenize(text):
    return [word for word in text.split() if word not in stop_words]

questions['tokens'] = questions['cleaned_text'].apply(tokenize)

# %%
lemmatizer = WordNetLemmatizer()

def lemmatize_tokens(tokens):
    return [lemmatizer.lemmatize(token) for token in tokens]

questions['tokens'] = questions['tokens'].apply(lemmatize_tokens)

# %%
questions['processed_text'] = questions['tokens'].apply(lambda tokens: ' '.join(tokens))

# %% [markdown]
# ### Vectorization

# %%
# Use unigrams only since questions are short
vectorizer = TfidfVectorizer(
    max_features=5000,       # limit vocabulary size to reduce memory usage
    min_df=5,                # ignore words appearing in fewer than 5 questions
    max_df=0.7,              # ignore very common words
    ngram_range=(1,1)        # unigrams
)

tfidf_matrix = vectorizer.fit_transform(questions['processed_text'])
print(tfidf_matrix.shape)  # (num_questions, 5000)
# Out:
# (100000, 5000)

# %%
from sklearn.decomposition import TruncatedSVD

n_components = 100  # start with 100 latent dimensions
svd = TruncatedSVD(n_components=n_components, random_state=42)
svd_matrix = svd.fit_transform(tfidf_matrix)

print(svd_matrix.shape)  # (num_questions, 100)
# Out:
# (100000, 100)

# %%
import numpy as np

terms = np.array(vectorizer.get_feature_names_out())
for i, comp in enumerate(svd.components_):
    top_terms = terms[np.argsort(comp)[-10:]]  # top 10 words for this component
    print(f"Component {i}: {', '.join(top_terms)}")
# Out:
# Component 0: crop, good, season, seed, bean, tomato, type, best, maize, plant
# Component 1: tree, rain, right, onion, cassava, carrot, season, want, banana, plant
# Component 2: pest, control, kg, fertilizer, best, bean, seed, planting, price, maize
# Component 3: way, breed, planting, soil, variety, season, crop, type, tomato, best
# Component 4: response, followed, reply, feed, good, dairy, milk, plant, get, cow
# Component 5: breed, feed, dairy, maize, milk, take, long, plant, best, cow
# Component 6: want, kg, one, price, good, much, market, seed, tomato, get
# Component 7: well, give, season, many, soil, grow, cow, good, crop, type
# Component 8: spray, disease, chemical, cause, control, type, maize, use, cow, tomato
# Component 9: take, optout, cabbage, soil, seed, response, followed, reply, good, type
# Component 10: chick, control, much, many, chicken, egg, hen, banana, use, bean
# Component 11: soya, season, tomato, planting, kg, crop, price, much, cow, bean
# Component 12: fertilizer, wilt, long, good, control, planting, use, plantation, get, banana
# Component 13: hw, wilt, tomato, price, one, plantation, kg, many, much, banana
# Component 14: get, seed, spray, day, potato, fertilizer, one, planting, use, many
# Component 15: poultry, lay, potato, time, start, egg, hen, season, planting, good
# Component 16: one, poultry, kg, planting, potato, farming, use, start, want, much
# Component 17: control, planting, bean, seed, farming, farm, poultry, start, want, many
# Component 18: many, pest, farm, cause, animal, good, much, potato, disease, control
# Component 19: kg, use, lay, type, potato, cow, egg, seed, much, hen
# Component 20: give, cabbage, use, feed, much, good, grow, chick, bean, seed
# Component 21: chick, irish, sweet, animal, disease, cause, grow, seed, price, potato
# Component 22: fertilizer, disease, much, chicken, get, type, chick, season, planting, cause
# Component 23: pig, well, farm, want, soil, control, chick, potato, hen, grow
# Component 24: good, use, many, dairy, cattle, breed, goat, pig, animal, cause
# Component 25: many, sweet, maize, pig, bean, well, much, potato, grow, chicken
# Component 26: rainy, many, use, coffee, disease, dry, pig, grow, cabbage, season
# Component 27: disease, know, goat, want, seed, animal, feed, give, planting, pig
# Component 28: grow, know, one, coffee, disease, cause, want, soil, planting, cabbage
# Component 29: egg, planting, dairy, control, soil, season, chicken, feed, farm, animal
# Component 30: cause, farming, soil, planting, price, cabbage, farm, feed, poultry, pig
# Component 31: give, breed, coffee, use, season, cause, one, pig, goat, soil
# Component 32: market, cow, chick, season, rabbit, feed, know, pig, cause, want
# Component 33: pig, medicine, variety, one, cause, birth, goat, cabbage, give, farm
# Component 34: want, milk, farming, planting, dairy, feed, cause, cabbage, control, goat
# Component 35: spray, medicine, much, birth, many, farming, time, animal, soil, give
# Component 36: bean, market, season, potato, rabbit, feed, farming, cabbage, soil, one
# Component 37: affect, chick, many, dairy, cabbage, goat, disease, feed, farm, soil
# Component 38: control, want, birth, poultry, coffee, cause, feed, market, give, rabbit
# Component 39: soil, tree, farming, chemical, used, give, spray, time, feed, coffee
# Component 40: weed, whats, planting, one, used, goat, chemical, rabbit, spray, time
# Component 41: one, production, chemical, spray, want, feed, milk, used, know, poultry
# Component 42: used, poultry, cow, like, feed, apply, onion, know, goat, fertilizer
# Component 43: market, like, need, farmer, know, chick, rabbit, milk, used, fertilizer
# Component 44: time, chemical, spray, disease, onion, cattle, milk, want, used, fertilizer
# Component 45: improve, right, chick, production, farmer, control, use, milk, fertilizer, time
# Component 46: would, livestock, give, wefarm, like, cattle, farming, know, onion, farmer
# Component 47: find, start, ready, poultry, milk, variety, goat, need, onion, market
# Component 48: whats, keep, want, help, need, hen, hw, wat, wefarm, farmer
# Component 49: start, area, hen, well, breed, whats, need, rabbit, variety, onion
# Component 50: rabbit, pest, production, time, farming, milk, egg, onion, month, wat
# Component 51: medicine, cattle, would, like, start, know, need, hen, wat, hw
# Component 52: like, time, price, milk, cattle, hen, breed, start, need, month
# Component 53: market, milk, livestock, farming, medicine, onion, month, hen, hw, whats
# Component 54: tree, need, passion, hen, milk, whats, fruit, melon, water, wat
# Component 55: goat, passion, water, milk, fruit, need, egg, variety, start, hw
# Component 56: hw, wat, onion, give, spacing, breed, egg, cattle, need, whats
# Component 57: fertilizer, well, breed, melon, dairy, hw, month, variety, water, cattle
# Component 58: way, cabbage, tomato, egg, onion, coffee, livestock, need, melon, water
# Component 59: make, tree, farmer, leaf, onion, melon, breed, passion, water, fruit
# Component 60: keeping, milk, growing, wefarm, day, water, would, cattle, like, start
# Component 61: give, keeping, like, area, market, sheep, feed, start, breed, livestock
# Component 62: weed, disease, market, hen, variety, day, spray, chemical, breed, wefarm
# Component 63: prevent, onion, rabbit, pest, dairy, egg, passion, fruit, medicine, wefarm
# Component 64: keep, tree, dry, keeping, weed, make, wefarm, dairy, food, livestock
# Component 65: hen, fruit, coffee, wat, fertilizer, production, dairy, day, livestock, spray
# Component 66: control, acre, land, tree, area, kg, planted, medicine, food, spray
# Component 67: problem, farming, sign, heat, gestation, make, sheep, period, day, cattle
# Component 68: wiki, sukuma, spray, day, livestock, leaf, tree, make, prevent, pest
# Component 69: gestation, wefarm, fruit, sheep, cattle, period, prevent, kg, pest, food
# Component 70: heat, acre, tree, gestation, bee, sheep, chick, variety, period, make
# Component 71: dry, production, prevent, planted, sheep, dairy, tree, area, gestation, period
# Component 72: mango, much, spacing, cattle, goat, chemical, problem, prevent, planted, tree
# Component 73: breed, medicine, plantation, weed, day, production, leaf, improve, food, cassava
# Component 74: way, month, yellow, could, calf, prevent, per, leaf, problem, kg
# Component 75: fertilizer, land, livestock, way, produce, weed, spray, cassava, growing, prevent
# Component 76: heat, sign, land, problem, spacing, cattle, improve, pest, cassava, growing
# Component 77: per, county, suitable, chemical, day, spacing, make, growing, tree, kg
# Component 78: production, prevent, whats, spacing, goat, improve, chemical, cassava, dry, area
# Component 79: spacing, know, period, used, method, county, produce, planted, well, cassava
# Component 80: spacing, gestation, yellow, produce, used, problem, dry, method, period, leaf
# Component 81: keeping, sheep, would, spacing, used, bee, spray, like, keep, planted
# Component 82: help, cost, name, cassava, livestock, chemical, pest, planted, weed, produce
# Component 83: sign, period, heat, rice, prevent, make, land, wiki, sukuma, planted
# Component 84: would, plantation, land, like, chemical, sheep, wiki, sukuma, keep, spacing
# Component 85: prevent, well, given, spray, cost, young, planted, sheep, grass, name
# Component 86: bee, keep, tree, well, period, harvest, way, name, wiki, sukuma
# Component 87: area, carrot, suitable, treat, yellow, chemical, planted, sheep, leaf, way
# Component 88: variety, county, problem, dry, breed, used, help, grass, spacing, way
# Component 89: help, rice, mature, like, watermelon, period, name, well, spacing, carrot
# Component 90: bee, acre, chemical, calf, problem, suitable, day, harvest, name, land
# Component 91: suitable, area, quality, bomet, spacing, tea, produce, name, improve, county
# Component 92: yellow, keep, heat, land, sign, day, grass, harvest, tea, leaf
# Component 93: manure, way, problem, land, spacing, name, county, plantation, carrot, cost
# Component 94: method, high, quality, garden, grass, yield, harvest, cost, produce, improve
# Component 95: sheep, manure, chemical, produce, apply, way, treat, like, plantation, carrot
# Component 96: spacing, rice, quality, area, high, yield, produce, watermelon, know, help
# Component 97: dry, young, cost, heat, sign, carrot, calf, harvest, help, county
# Component 98: name, calf, produce, county, mature, carrot, keep, garden, land, dry
# Component 99: produce, manure, cost, kind, rice, heat, mature, sign, treat, calf

# %%
svd.explained_variance_ratio_.sum()
# Out:
# np.float64(0.3435559339775962)

# %%
from sklearn.cluster import KMeans

n_clusters = 10  # start with ~10 clusters, adjust after exploration
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
labels = kmeans.fit_predict(svd_matrix)

questions['cluster'] = labels

# %%
import numpy as np

# Get the cluster centers in the reduced SVD space
centers = kmeans.cluster_centers_

# Project centers back to TF-IDF space to identify top words
# (This uses the SVD components to approximate the original feature space)
terms = vectorizer.get_feature_names_out()
components = svd.components_

for i in range(n_clusters):
    # approximate cluster center in original space
    center_tfidf = centers[i].dot(components)

    top_indices = center_tfidf.argsort()[::-1][:15]
    top_terms = [terms[idx] for idx in top_indices]

    print(f"\nCluster {i}:")
    print(", ".join(top_terms))
# Out:
# Cluster 0:
# cow, maize, get, type, much, good, tomato, cause, disease, chicken, give, bean, chick, animal, one
#
# Cluster 1:
# take, long, mature, many, harvest, day, month, harvested, ready, birth, maize, cow, grow, tomato, give
#
# Cluster 2:
# crop, plant, best, rotation, season, grow, type, grown, maize, pest, soil, area, well, production, good
#
# Cluster 3:
# hen, egg, lay, many, laying, chicken, eating, day, hatch, give, problem, cause, layer, eat, keep
#
# Cluster 4:
# best, maize, plant, type, tomato, variety, seed, planting, season, breed, way, fertilizer, cow, bean, time
#
# Cluster 5:
# plant, maize, tomato, bean, want, banana, season, good, type, seed, potato, many, one, time, cabbage
#
# Cluster 6:
# reply, followed, response, optout, stop, plant, maize, best, cow, type, use, tomato, asks, crop, bean
#
# Cluster 7:
# use, chemical, spray, maize, fertilizer, medicine, method, type, plant, tomato, manure, bean, best, control, treat
#
# Cluster 8:
# tree, plant, mango, seedling, many, coffee, dry, garden, suitable, mature, planted, fruit, manure, harvest, planting
#
# Cluster 9:
# price, maize, bean, kg, current, per, market, whats, rice, da, coffee, get, know, de, ov

# %%
questions.loc[questions['cluster'] == 6, 'question_content'].sample(30, random_state=42)
# Out:
# 521258    Fred asks: When onion seedlings are destroyed ...
# 991463    A farmer asks: Kibet asks: What is the price o...
# 183745    Ronald asks: The advise about the drying of my...
# 315347    Mutebi asks,' in case afarmer follow all the r...
# 980547    Twinamatsiko asks: which maize varieties are h...
# 123305    A farmer asks: My maize has been seriously att...
# 891384    A farmer asks: what is the price of ayellow be...
# 269092    Betty asks: Why should legumes seeds be inocul...
# 664666    Farida asks: how is avocado trees crafted Repl...
# 279639    Joram asks: when is spraying maize crops with ...
# 153240    Matsiko asks: Which drug is given to a cow saf...
# 476727    Fancy asks: What is the botanical name of maiz...
# 418681    James asks: What is science tecnology? Reply Q...
# 482286    Amon asks: Mention 4 methods of controlling so...
# 886358    Q sodom asks: My maize plantation has earthwor...
# 704857    <6333>,  A farmer asks: How Long Does It Take ...
# 746521    Mark asks: but wat is de uze of rosemary plant...
# 615535    A farmer asks: What is the best local type of ...
# 4196      Richard asks: Which cash crop should the yaung...
# 915887    A farmer asks: which type of bags is suitable ...
# 330964    Felix asks: i have my hens they are always lik...
# 730785    Q Benard asks: which is the best preventives c...
# 220793    Benard asks: Which time can i plant tomatoes R...
# 131163    A farmer asks: when you have plant maize. how ...
# 116853    Ryan asks: how long does a cow have to take to...
# 904433    Edith asks: how much with a coffee Reply Q3 fo...
# 818808    Ronald asks: Among the 2 types of rice grown i...
# 354941    Joxhef asks: how to plant tea!!??& which spaci...
# 584210    Jackson asks: What iz herbicide selectivity? R...
# 115490    Ivan asks: MY COW HAS BEEN DHIARATING FOR NOW ...
# Name: question_content, dtype: object

# %%
# junk_terms = ["reply", "followed", "optout", "stop"]
junk_terms = ["Dady Wa Penny"]
mask = questions['question_content'].str.contains(
    '|'.join(junk_terms),
    case=False,
    na=False
)

junk_subset = questions[mask]
print(junk_subset.shape)
# Out:
# (1, 28)

# %%
for a in junk_subset['question_content']:
    print(a)
# Out:
# Dady Wa Penny asks: How many months does a broiler take to be sold at 40000 0757184764Reply Q542 followed by your response.
#
# optout stop 6333

# %%
for question in junk_subset.sample(30, random_state=42)['question_content']:
    print(question)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 for question in junk_subset.sample(30, random_state=42)['question_content']:
#       2     print(question)
#
# File c:\Users\ruggb\anaconda3\envs\datascience\Lib\site-packages\pandas\core\generic.py:6137, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    6134 if weights is not None:
#    6135     weights = sample.preprocess_weights(self, weights, axis)
# -> 6137 sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    6138 result = self.take(sampled_indices, axis=axis)
#    6140 if ignore_index:
#
# File c:\Users\ruggb\anaconda3\envs\datascience\Lib\site-packages\pandas\core\sample.py:152, in sample(obj_len, size, replace, weights, random_state)
#     149     else:
#     150         raise ValueError("Invalid weights: weights sum to zero")
# --> 152 return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     153     np.intp, copy=False
#     154 )
#
# File numpy\\random\\mtrand.pyx:1020, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'
