# %%
from dotenv import load_dotenv
import os
import duckdb
import pandas as pd

load_dotenv()

csv_path = os.getenv("DATA_CSV")
parquet_path = os.getenv("DATA_PARQUET")
sample_path = os.getenv("DATA_SAMPLE")

# %% [markdown]
# Converts large .csv file to .parquet and checks conversion. Outputs basic info on dataset.

# %%
if not os.path.exists(parquet_path):
    duckdb.query(f"""
    COPY (
        SELECT *
        FROM read_csv_auto(
            '{csv_path}',
            ignore_errors = true,
            sample_size = -1,
            all_varchar = true
        )
    ) TO '{parquet_path}' 
    (FORMAT PARQUET, OVERWRITE TRUE);
    """)
else:
    print(f"Parquet file already exists at {parquet_path}, skipping conversion.")
# Out:
# Parquet file already exists at D:\ruggbk\datasets\farmersdirect\b0cd514b-b9cc-4972-a0c2-c91726e6d825.parquet, skipping conversion.

# %%
# Count rows in original CSV
original_rows = duckdb.query(f"""
    SELECT COUNT(*) FROM read_csv_auto(
        '{csv_path}',
        ignore_errors = true,
        sample_size = -1
    )
""").fetchall()[0][0]

# %%
# Count rows in Parquet
parquet_rows = duckdb.query(f"""
    SELECT COUNT(*) FROM '{parquet_path}'
""").fetchall()[0][0]

print(f"Original rows (with ignored errors): {original_rows}")
print(f"Parquet rows: {parquet_rows}")
# Out:
# Original rows (with ignored errors): 20304843
# Parquet rows: 20304843

# %%
unique_question_count = duckdb.query(f"""
    SELECT COUNT(DISTINCT question_content)
    FROM '{parquet_path}'
""").fetchall()[0][0]
print(f"# of Unique Questions: {unique_question_count}")
# Out:
# # of Unique Questions: 5452290

# %%
unique_rows_maincolumns = duckdb.query(f"""
    SELECT COUNT(DISTINCT ROW(question_id, question_content, question_topic,response_id, response_content))
    FROM '{parquet_path}'
""").fetchall()[0][0]
print(f"# of Unique Rows: {unique_rows_maincolumns}")
# Out:
# # of Unique Rows: 18854432

# %%
unique_response_count = duckdb.query(f"""
    SELECT COUNT(DISTINCT response_id)
    FROM '{parquet_path}'
""").fetchall()[0][0]
print('# of Unique Responses: ' + str(unique_response_count))
# Out:
# # of Unique Responses: 16283143

# %%
df = pd.read_parquet(parquet_path)
df.shape  # (rows, columns)
df.info()  # column types and non-null counts
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20304843 entries, 0 to 20304842
# Data columns (total 24 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   question_id                 object
#  1   question_user_id            object
#  2   question_language           object
#  3   question_content            object
#  4   question_topic              object
#  5   question_sent               object
#  6   response_id                 object
#  7   response_user_id            object
#  8   response_language           object
#  9   response_content            object
#  10  response_topic              object
#  11  response_sent               object
#  12  question_user_type          object
#  13  question_user_status        object
#  14  question_user_country_code  object
#  15  question_user_gender        object
#  16  question_user_dob           object
#  17  question_user_created_at    object
#  18  response_user_type          object
#  19  response_user_status        object
#  20  response_user_country_code  object
#  21  response_user_gender        object
#  22  response_user_dob           object
#  23  response_user_created_at    object
# dtypes: object(24)
# memory usage: 3.6+ GB

# %%
df.head()
# Out:
#   question_id question_user_id question_language  \
# 0     4107104           574194               eng
# 1     4107104           574194               eng
# 2     4107104           574194               eng
# 3     4107104           574194               eng
# 4     4107104           574194               eng
#
#                                     question_content question_topic  \
# 0  Q How can i start with one hen which is a laye...        chicken
# 1  Q How can i start with one hen which is a laye...        chicken
# 2  Q How can i start with one hen which is a laye...        chicken
# 3  Q How can i start with one hen which is a laye...        chicken
# 4  Q How can i start with one hen which is a laye...        chicken
#
#             question_sent response_id response_user_id response_language  \
# 0  2017-12-08 19:04:04+00     4215434           574940               eng
# 1  2017-12-08 19:04:04+00     4207349           574940               eng
# 2  2017-12-08 19:04:04+00     4215309           574940               eng
# 3  2017-12-08 19:04:04+00     4200211           574940               eng
# 4  2017-12-08 19:04:04+00     4205121           574940               eng
#
#                                     response_content  ...  \
# 0        Q1 they should answer as hurry as possible.  ...
# 1        Q1 they should answer as hurry as possible.  ...
# 2                      Q1 like which types of traps?  ...
# 3  Q1 if it is well fed , it takes 1 mnth 2 lay e...  ...
# 4                                     Q1 by digging.  ...
#
#   question_user_country_code question_user_gender question_user_dob  \
# 0                         ug                 None              None
# 1                         ug                 None              None
# 2                         ug                 None              None
# 3                         ug                 None              None
# 4                         ug                 None              None
#
#   question_user_created_at response_user_type response_user_status  \
# 0   2017-12-08 10:50:34+00             farmer               zombie
# 1   2017-12-08 10:50:34+00             farmer               zombie
# 2   2017-12-08 10:50:34+00             farmer               zombie
# 3   2017-12-08 10:50:34+00             farmer               zombie
# 4   2017-12-08 10:50:34+00             farmer               zombie
#
#   response_user_country_code response_user_gender response_user_dob  \
# 0                         ug                 None              None
# 1                         ug                 None              None
# 2                         ug                 None              None
# 3                         ug                 None              None
# 4                         ug                 None              None
#
#   response_user_created_at
# 0   2017-12-08 18:33:04+00
# 1   2017-12-08 18:33:04+00
# 2   2017-12-08 18:33:04+00
# 3   2017-12-08 18:33:04+00
# 4   2017-12-08 18:33:04+00
#
# [5 rows x 24 columns]

# %%
# Saves random sample of 1 million English questions / responses in DuckDB
if not os.path.exists(sample_path):
    duckdb.query(f"""
        COPY (
            SELECT *
            FROM read_parquet('{parquet_path}')
            WHERE question_language = 'eng'
              AND response_language = 'eng'
              AND response_content IS NOT NULL
            ORDER BY RANDOM()
            LIMIT 1000000
        ) TO '{sample_path}' (FORMAT PARQUET, OVERWRITE TRUE);
    """)
    print(f"Sample saved to {sample_path}")
else:
    print(f"Sample file already exists at {sample_path}, skipping sampling.")
# Out:
# Sample file already exists at D:\ruggbk\datasets\farmersdirect\farmers_1mil_eng_sample.parquet, skipping sampling.

# %%
# check sampling
pd.read_parquet(sample_path)
# Out:
#        question_id question_user_id question_language  \
# 0         50871840          2942156               eng
# 1         24215668          1004601               eng
# 2         34970005          2697773               eng
# 3         47631987           963431               eng
# 4         56862473          3474362               eng
# ...            ...              ...               ...
# 999995     5338768           359662               eng
# 999996    29654231          2361244               eng
# 999997     7105245           938846               eng
# 999998    22633493          1968918               eng
# 999999    39832583          3005123               eng
#
#                                          question_content question_topic  \
# 0             Q Why Wefarm Doesn't Prepare Our Promotion?           None
# 1                                   what is mixed farming           None
# 2          Q to 6333 wc diseases that attack maize plant?          plant
# 3                        What type of maize is good plant          maize
# 4                                 Q what are the seedling           None
# ...                                                   ...            ...
# 999995         How will you know that your cow is on heat         cattle
# 999996  Which pest that attack the root of tea and how...            tea
# 999997           Which Chemical Is Best In Weeding Maize?          maize
# 999998  Q HOW DO YOU DO AWAY WITH ACCUMULATED WASTES L...         cattle
# 999999  Q,within how many day top dressing is carry ou...         potato
#
#                         question_sent response_id response_user_id  \
# 0       2020-12-02 17:00:20.667286+00    50872828           269315
# 1        2019-04-25 15:07:44.78925+00    24222344           225067
# 2       2019-12-03 07:19:06.001165+00    34970061          1844517
# 3       2020-09-30 12:14:43.623567+00    47632870          3249306
# 4       2021-05-26 19:02:20.503138+00    56888364          3327551
# ...                               ...         ...              ...
# 999995  2018-03-24 16:00:30.163638+00     5345552           389259
# 999996  2019-08-08 18:18:55.308216+00    29671088          1359668
# 999997  2018-06-26 15:38:23.882541+00     7109077           539166
# 999998  2019-03-19 16:13:04.663386+00    22633848          1846683
# 999999   2020-04-06 18:01:37.58457+00    39835546          2991086
#
#        response_language                                   response_content  \
# 0                    eng           Q451 it is the work of the org committee
# 1                    eng  Q 418 Refers to growing of various crops on sa...
# 2                    eng                                         I don't no
# 3                    eng  if for selling,popckons  but if for food consu...
# 4                    eng  Q22 seedling are grown plants in seedbed for t...
# ...                  ...                                                ...
# 999995               eng                      Q16 the cow mounts other cows
# 999996               eng      Q99;Red ants, control used  THUNDER chemical.
# 999997               eng                                    Q 105 dual gold
# 999998               eng                                         q11 deworm
# 999999               eng                                         Q87.4weeks
#
#         ... question_user_country_code question_user_gender question_user_dob  \
# 0       ...                         ug                 None              None
# 1       ...                         ug                 None              None
# 2       ...                         ug                 None              None
# 3       ...                         ug                 None              None
# 4       ...                         ke                 None              None
# ...     ...                        ...                  ...               ...
# 999995  ...                         ke                 None              None
# 999996  ...                         ke                 None              None
# 999997  ...                         ke                 None              None
# 999998  ...                         ke                 None              None
# 999999  ...                         ke                 None              None
#
#              question_user_created_at response_user_type response_user_status  \
# 0       2020-03-06 13:36:15.449684+00             farmer                 live
# 1       2018-07-20 14:24:34.186844+00             farmer                 live
# 2       2019-11-25 15:12:45.486055+00             farmer                 live
# 3       2018-07-04 06:58:43.074057+00             farmer                 live
# 4       2020-11-27 08:44:57.419151+00             farmer                 live
# ...                               ...                ...                  ...
# 999995         2017-09-14 17:17:13+00             farmer               zombie
# 999996   2019-08-08 17:30:38.90231+00             farmer                 live
# 999997  2018-06-26 04:23:44.463892+00             farmer                 live
# 999998  2019-03-19 15:58:37.464951+00             farmer               zombie
# 999999  2020-04-02 17:32:32.859002+00             farmer                 live
#
#        response_user_country_code response_user_gender response_user_dob  \
# 0                              ug                 None              None
# 1                              ug                 male        1984-10-28
# 2                              ug                 None              None
# 3                              ug                 None              None
# 4                              ke                 None              None
# ...                           ...                  ...               ...
# 999995                         ke                 None              None
# 999996                         ke                 None              None
# 999997                         ke                 None              None
# 999998                         ke                 None              None
# 999999                         ke                 None              None
#
#              response_user_created_at
# 0              2017-07-20 11:24:28+00
# 1              2017-06-12 17:02:07+00
# 2       2019-01-23 12:54:10.444483+00
# 3       2020-07-26 16:23:11.415517+00
# 4       2020-09-17 17:53:24.140724+00
# ...                               ...
# 999995         2017-09-26 04:29:58+00
# 999996  2018-10-18 17:42:49.166605+00
# 999997         2017-11-27 06:38:06+00
# 999998  2019-01-23 17:55:02.988204+00
# 999999  2020-03-26 17:31:20.888983+00
#
# [1000000 rows x 24 columns]
