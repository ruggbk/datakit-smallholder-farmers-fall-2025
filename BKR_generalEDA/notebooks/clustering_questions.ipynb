# %%
import pandas as pd
import numpy as np
from dotenv import load_dotenv
import os
import duckdb
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import silhouette_score
import nltk

# Import from local modules
import sys
sys.path.append('../src')

from cleaning import clean_text, tokenize, lemmatize_tokens

# Download necessary NLTK resources
import nltk
nltk.download('wordnet')
nltk.download('stopwords')

# Path for 1 million English sample questions
load_dotenv()
sample_path = os.getenv("DATA_SAMPLE")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ruggb\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ruggb\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Clustering on question content (English)

# %% [markdown]
# ### Prepare sample dataset

# %%
dataset = pd.read_parquet(sample_path)

# Drop duplicate questions
questions_raw = dataset.drop_duplicates(subset='question_content', keep='first')

# Random sample of rows, reproducible with random_state
questions = questions_raw.sample(n=100000, random_state=42)

# %% [markdown]
# ### Text Processing

# %%
def process_text(text: str) -> str:
    cleaned = clean_text(text)
    tokens = tokenize(cleaned)
    lemmas = lemmatize_tokens(tokens)
    return " ".join(lemmas)

questions['processed_text'] = questions['question_content'].apply(process_text)

# %% [markdown]
# ### Vectorization

# %%
# Use unigrams only since questions are short
vectorizer = TfidfVectorizer(
    max_features=5000,       # limit vocabulary size to reduce memory usage
    min_df=5,                # ignore words appearing in fewer than 5 questions
    max_df=0.7,              # ignore very common words
    ngram_range=(1,3)        # unigrams to bigrams
)

tfidf_matrix = vectorizer.fit_transform(questions['processed_text'])
print(tfidf_matrix.shape)  # (num_questions, 5000)
# Out:
# (100000, 5000)

# %%
import numpy as np

scalar = np.array(5)
vector = np.array([1, 2, 3])
matrix = np.array([[1, 2], [3, 4]])
tensor3 = np.random.randn(2, 3, 4)

print(scalar.ndim)   # 0
print(vector.ndim)   # 1
print(matrix.ndim)   # 2
print(tensor3.ndim)  # 3
print(tensor3)
print(matrix)
# Out:
# 0
# 1
# 2
# 3
# [[[-0.88479356 -2.18800026  0.05385855 -0.74653956]
#   [-2.92511831  0.21169566  0.17527344  0.26825658]
#   [-0.32001963 -0.9959532  -0.76953611  0.88065008]]
#
#  [[ 0.98609026 -0.15849071  0.94032672 -1.4289246 ]
#   [ 2.85920125  0.68471709  0.23028841 -0.75983649]
#   [ 1.03438812  0.11245826 -1.75458845  0.22032017]]]
# [[1 2]
#  [3 4]]

# %%
from sklearn.decomposition import TruncatedSVD

n_components = 100  # start with 100 latent dimensions
svd = TruncatedSVD(n_components=n_components, random_state=42)
svd_matrix = svd.fit_transform(tfidf_matrix)

print(svd_matrix.shape)  # (num_questions, 100)
# Out:
# (100000, 100)

# %%
terms = np.array(vectorizer.get_feature_names_out())
for i, comp in enumerate(svd.components_):
    top_terms = terms[np.argsort(comp)[-10:]]  # top 10 words for this component
    print(f"Component {i}: {', '.join(top_terms)}")
# Out:
# Component 0: reply qnum_token, followed, qnum_token, type, tomato, reply, num_token, best, maize, plant
# Component 1: season, seed, num_token, bean, type, tomato, plant maize, best, maize, plant
# Component 2: qnum_token, response, followed response, qnum_token followed response, followed, reply qnum_token followed, reply qnum_token, qnum_token followed, plant maize, plant
# Component 3: seed, maize seed, planting, bean, plant maize, price maize, crop, best, price, maize
# Component 4: rotation, type crop, use, season, grow, soil, type, tomato, best, crop
# Component 5: animal, crop, dairy cow, dairy, cause, plant, milk, maize, best, cow
# Component 6: grow, rotation, many, plant, num_token, maize, cow, long, take, crop
# Component 7: good, dairy, plant, best, get market, crop, seed, market, cow, get
# Component 8: want, hen, disease, banana, poultry, control, animal, cause, use, num_token
# Component 9: maize, disease, crop, much, cow, control, get, cause, use, tomato
# Component 10: long, poultry, get, animal, bean, control, banana plantation, plantation, use, banana
# Component 11: type, plant bean, planting, banana, price, cow, much, num_token, use, bean
# Component 12: cause, chick, price, animal, chicken, egg, poultry, hen, much, bean
# Component 13: use spray, medicine use, good, medicine, chemical use, spray, chemical, get, type, use
# Component 14: many type, chicken, one, banana, egg, good, much, hen, many, type
# Component 15: seed, type maize, num_token, many, soil, bean, good, cause, animal, type
# Component 16: type, long, use, start, poultry, want, farm, farming, animal, much
# Component 17: know, good, poultry farming, control, bean, start, farm, want, farming, poultry
# Component 18: cattle, potato, num_token, use, seed, soil, long, type, much, cause
# Component 19: many month, bean, day, month, cause, seed, one, farm, control, many
# Component 20: egg, long, animal, farm, type, disease, much, bean, hen, control
# Component 21: banana, bean, start, egg, animal, good, planting, want, hen, seed
# Component 22: egg, irish, sweet potato, sweet, price, soil, hen, farm, control, potato
# Component 23: cabbage, price maize, use, maize seed, disease, poultry, type, control, price, seed
# Component 24: disease, grow, pig, chick, control, potato, want, good, seed, chicken
# Component 25: sweet, season, animal, disease, farming, planting, good, potato, poultry, chicken
# Component 26: disease, price, old, potato, give, good, seed, one, poultry, chick
# Component 27: breed, coffee, use, cattle, seed, price, goat, pig, farm, good
# Component 28: erosion, cow, planting, animal, one, price, chick, chicken, soil, farm
# Component 29: type soil, goat, planting, soil erosion, erosion, many, good, farming, control, soil
# Component 30: tomato, cow, wat, potato, seed, feed, soil, grow, poultry, pig
# Component 31: tomato, bean, sheep, farming, give, seed, dairy, soil, potato, goat
# Component 32: farm, prevent, attack, poultry, affect, know, soil, rabbit, planting, disease
# Component 33: make, coffee, grow well, fruit, season, well, poultry, cabbage, goat, grow
# Component 34: season, passion, give, fruit, coffee, planting, wefarm, one, farmer, farming
# Component 35: many, planting, much, season, goat, coffee, give, poultry, wefarm, farmer
# Component 36: cattle, seed, best, one, get market, wefarm, good, farmer, market, rabbit
# Component 37: sheep, rabbit, give, know, market, control, planting, goat, poultry, one
# Component 38: like, long, get, best, know, farmer, pig, good, coffee, one
# Component 39: used, wat, tree, give, whats, feed, poultry, passion fruit, passion, fruit
# Component 40: like, chick, wefarm, farmer, know, need, pig, goat, plant cabbage, cabbage
# Component 41: milk, disease, farmer, planting, cabbage, want, wefarm, one, cattle, wat
# Component 42: one, give birth, birth, livestock, want, fertilizer, coffee, planting, grow, give
# Component 43: milk, production, grow, rabbit, dairy cow, farmer, dairy, planting, cattle, feed
# Component 44: would like, would, fertilizer, cabbage, used, like, know, feed, wat, coffee
# Component 45: seed, dairy, chick, get market, want, goat, feed, coffee, farmer, market
# Component 46: spray, dry, milk, want, coffee, feed, season, give, cattle, cabbage
# Component 47: fruit, leaf, best feed, season, get, whats, cabbage, rabbit, wefarm, feed
# Component 48: farming, give, onion, dairy, feed, disease, coffee, get market, market, wefarm
# Component 49: pig, rabbit, spray, chemical, water, problem, cattle, wefarm, used, whats
# Component 50: know, market, want, milk, feed, production, wat, used, whats, livestock
# Component 51: spray, chemical, onion, water melon, livestock, melon, feed, used, water, need
# Component 52: cattle, problem, time, farmer, water melon, melon, hen, feed, water, whats
# Component 53: variety, melon, use, production, water, start, milk, whats, livestock, need
# Component 54: rabbit, farming, plant water, produce, production, milk, egg, water melon, melon, water
# Component 55: plant onion, chemical, lay, give, disease, fertilizer, need, whats, egg, onion
# Component 56: water, feed, sheep, time plant, livestock, best time, many time, problem, egg, time
# Component 57: improve, chicken, plant onion, milk production, produce, production, hen, time, onion, milk
# Component 58: top, know, cattle, farming, type fertilizer, season, fertilizer use, apply, best fertilizer, fertilizer
# Component 59: livestock, dairy goat, many time, wat, give, need, whats, dairy cow, time, dairy
# Component 60: rabbit, prevent, planted, plant onion, dairy cow, variety, hw, livestock, dairy, onion
# Component 61: hw plant, time, way, hw much, farming, know, prevent, whats, need, hw
# Component 62: bee, want start, would, dairy cow, keeping, like, dairy, fertilizer, hw, start
# Component 63: feed, well, egg, area, hw, county, best variety, start, medicine, variety
# Component 64: could problem, variety, bee, calf, could, dairy, leaf, tree, make, problem
# Component 65: rabbit, medicine use, pest, onion, cattle, goat, best way, way, medicine, make
# Component 66: calf, many month, production, hw, medicine use, spray, dairy, problem, month, medicine
# Component 67: feed, leaf, spray, tree, pest, best breed, make, medicine, sheep, breed
# Component 68: prevent, sheep, know, num_token month, variety, time, bee, many month, make, month
# Component 69: weed, area, sheep, land, bee, medicine, used, banana plantation, method, plantation
# Component 70: leaf, county, bird, well, area, garden, pest, fertilizer, variety, prevent
# Component 71: grass, food, goat, prevent, chemical, banana plantation, weed, spray, plantation, tree
# Component 72: best way, know, time, land, planted, way, banana, bee, used, tree
# Component 73: weed, know, best way, period, dairy, tree, variety, grass, way, sheep
# Component 74: weed, dry, bee, grass, spray, area, best way, well, breed, way
# Component 75: improve, best way, land, pest, sheep, way, tree, sukuma wiki, wiki, sukuma
# Component 76: calf, pest, variety, hive, plantation, tree, keep, keeping, day, bee
# Component 77: best food, acre, grass, importance, help, sheep, spray, land, bee, food
# Component 78: acre, problem, prevent, well, plantation, start, heat, sign, land, know
# Component 79: weed, name, dry, planted, method, day, well, know, food, area
# Component 80: napier, planted, improve, bee, heat, production, name, sign, leaf, grass
# Component 81: way, mature, cost, garden, medicine, leaf, improve, food, production, weed
# Component 82: make, spray, area, rice, production, cassava, plantation, food, improve, pest
# Component 83: calf, way, used, leaf, fish, breed, variety, name, help, food
# Component 84: milk, method, keep, mean, produce, weed, gestation period, gestation, period, pest
# Component 85: know, day, pest, name, help, production, improve, cost, land, calf
# Component 86: cost, growing, planted, garden, heat, spacing, weed, pest, sign, help
# Component 87: rice, weed, pest, produce, variety, name, spray, cost, method, help
# Component 88: growing, pest, name, chemical, many, cassava, calf, spacing, dry, area
# Component 89: layer, planted, gestation period, gestation, importance, know, period, tea, spacing, help
# Component 90: heat, cassava, growing, breed, food, mean, carrot, spray, sign, name
# Component 91: method, chemical, county, pest, land, growing, weed, spacing, name, well
# Component 92: breed, name, grass, problem, fish, period, cost, chemical use, medicine, chemical
# Component 93: iz, garden, rice, cost, spacing, chemical, cassava, name, watermelon, planted
# Component 94: rain, treat, irish, month, suitable, produce, day, growing, leaf, land
# Component 95: sweet, bed, garden, produce, mean, planted, carrot, improve, importance, tea
# Component 96: sweet, produce, garden, rain, well, tea, rice, cassava, growing, keep
# Component 97: method, cost, produce, spacing, watermelon, tea, mature, improve, growing, mean
# Component 98: growing, calf, tea, mean, treat, harvest, plant maize, irish potato, irish, well
# Component 99: sugarcane, harvest, production, fish, growing, cost, suitable, iz, importance, mean

# %%
svd.explained_variance_ratio_.sum()
# Out:
# 0.2634808542488822

# %%
from sklearn.cluster import KMeans

n_clusters = 10  # start with ~10 clusters, adjust after exploration
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
labels = kmeans.fit_predict(svd_matrix)
# labels = kmeans.fit_predict(tfidf_matrix)

questions['cluster'] = labels

# %%
components
# Out:
# array([[ 6.43422339e-04,  5.46400547e-04,  7.90791975e-04, ...,
#          1.88775162e-03,  1.11616951e-03,  8.77849127e-04],
#        [ 2.61079688e-04,  2.15373044e-04,  3.98619747e-04, ...,
#          9.86103551e-05,  7.52462333e-05,  4.96317860e-04],
#        [-2.82451286e-04, -7.19259350e-04, -5.53282083e-04, ...,
#         -4.54766501e-03, -2.89555505e-03, -5.16261928e-06],
#        ...,
#        [ 2.52454786e-04, -1.33521869e-03,  2.18140461e-04, ...,
#          2.90958454e-03,  3.58260714e-03,  2.43563603e-03],
#        [-2.21014677e-05, -2.00575098e-04, -5.92249639e-04, ...,
#         -2.17844988e-03, -1.48048529e-03,  2.67350469e-03],
#        [-7.64164683e-04,  1.35971949e-03,  8.91159368e-05, ...,
#          3.34814461e-03,  2.75808046e-03,  1.72182639e-04]])

# %%
import numpy as np

# Get the cluster centers in the reduced SVD space
centers = kmeans.cluster_centers_

# Project centers back to TF-IDF space to identify top words
# (This uses the SVD components to approximate the original feature space)
terms = vectorizer.get_feature_names_out()
components = svd.components_

for i in range(n_clusters):
    # approximate cluster center in original space
    center_tfidf = centers[i].dot(components)

    top_indices = center_tfidf.argsort()[::-1][:15]
    top_terms = [terms[idx] for idx in top_indices]

    print(f"\nCluster {i}:")
    print(", ".join(top_terms))
# Out:
# Cluster 0:
# egg, lay, hen, lay egg, egg plant, hen lay, chicken, layer, many, plant, laying, many egg, hen lay egg, eating, num_token
#
# Cluster 1:
# plant, best, tomato, crop, num_token, bean, use, banana, type, animal, chicken, take, cause, control, good
#
# Cluster 2:
# milk, cow, production, produce, milk production, cow produce, increase, dairy, produce milk, milk cow, goat, give, high, breed, calf
#
# Cluster 3:
# maize, plant, plant maize, best, maize plant, seed, price, price maize, type, planting, num_token, bean, maize seed, type maize, use
#
# Cluster 4:
# one, many, acre, plant, young, one acre, chick, young one, maize, num_token, old, much, day, best, one best
#
# Cluster 5:
# get, market, get market, seed, num_token, good, chick, get good, plant, seedling, get seed, want, county, much, maize
#
# Cluster 6:
# rabbit, market, urine, market rabbit, breed, get, rabbit urine, type rabbit, best, feed, disease, num_token, breed rabbit, young, food
#
# Cluster 7:
# cow, dairy, dairy cow, heat, feed, problem, best, give, cause, sign, num_token, many, know, pregnant, salt
#
# Cluster 8:
# hen, num_token, treat, hen lay, keep, give, disease, medicine, use, cock, problem, give hen, feed, num_token hen, lay
#
# Cluster 9:
# give, need, fertilizer, water, melon, water melon, num_token, plant, best, type, birth, use, apply, best fertilizer, give birth

# %%
terms = vectorizer.get_feature_names_out()
centers = kmeans.cluster_centers_

for i in range(n_clusters):
    top_indices = centers[i].argsort()[::-1][:15]  # top 15 words in TF-IDF space
    top_terms = [terms[idx] for idx in top_indices]
    print(f"\nCluster {i}:")
    print(", ".join(top_terms))
# Out:
# Cluster 0:
# advisable plant, acalf, access, _how, acre, advisable num_token, acre farm, advisable plant maize, acow, afarmer control, abortion, advice give, afemale, afamer, administer
#
# Cluster 1:
# _how, abanana plant, abt, achicken, _what, abortion, acalf, acre maize, according, absoluta, achieve, ad, advice best, across, agoat
#
# Cluster 2:
# advisable use, abaut, advisable feed, advisable num_token, _how, actelic, advantage, advice give, able, administer, afemale, acre produce, afarm, adding, advisable plant
#
# Cluster 3:
# abanana, _how, _what, abaut, abig, absoluta, acre, acow, acaricide, access, actelic, advantage, act, ad, add
#
# Cluster 4:
# adairy cow, aday, _how, activity, acidic, acre piece land, adding, access, acalf, acrop, acre maize, _what, adairy, actelic, adisease
#
# Cluster 5:
# able, _how, absoluta, acaricide, abt, _what, acow, ad, aday, abig, advantage using, acidic, acid, adisease, advisable
#
# Cluster 6:
# adairy, advantage using, action, _how, administered, administer, advice best, adairy cow, afamer, advisable num_token, achicken, acalf, afected, acre produce, access
#
# Cluster 7:
# abaut, _how, able, abull, abig, absoluta, advisable, afamer, achieve, act, acre farm, acre, acow, acre piece, adviceable
#
# Cluster 8:
# acre, advisable use, acalf, acre farm, access, acow, advisable, _how, abortion, adviceable, acre piece land, abt, action, advisable feed, activity
#
# Cluster 9:
# _how, adviceable, advise, advisable feed, adisease, advisable num_token, advisable plant, activity, _what, abanana plant, achicken, ad, advantage, abortion, acre maize

# %%
questions.loc[questions['cluster'] == 7, 'question_content'].sample(30, random_state=42)
# Out:
# 55671     Q If yes, why is it atvaseble to feed cows wit...
# 896503    I HAVE FARM OF ANIMAL I HAVE MANY COWS AND GOA...
# 787196    Q my cow was brown but its colour at the backl...
# 811648    Q,what Are The X-stic Of A Good Cow Which Can ...
# 513092                Q.what cause stunted growth in a cow?
# 99457            Q.my cow irinating blood.is there medicine
# 99856     Q how will I know expectant cow is well, which...
# 626529    Q: what kind of medicine do I give my cow whos...
# 670092                    Q what is gestation period of cow
# 474226    Q: my cow gave birth yesterday, and upto now i...
# 768977                       QWhat can i done to an old cow
# 492417         Q which type of feeds is best in dairy cow ,
# 364553    Hw can i know dat te dairy cow is suffering 4r...
# 912056    Q which type of medicine can i use to treat my...
# 47446     How should the discharge of a pregnant cow loo...
# 886100                      Q.How much is asack of cow peas
# 874609    Q my cow normally when its on heat period and ...
# 803297    Q  How  will  i  help  the  cow when  is  over...
# 6577             Which salt can give to cow (komach kirkit)
# 5181      Q my cow is passing whitish things like mucus....
# 942118                                  How Does A Cow Grow
# 347793                                Q I WANT TO KEPT COWS
# 902279    my cow hv broblem in breast ina toa damu tym y...
# 301891       Qhow long did heifer cow need to be given AI ?
# 65146                        Q what cause coughing in a cow
# 295710         what the best tym to knw when cow is on heat
# 824013    Q   How can I know that  the cow needs abull!\...
# 441485    How can you plant bananas using cow dung,can i...
# 438462    Time of salt giving,,,,in some cases its becz ...
# 509256                Q WHAT CAUSES LACK OF CALCIUM TO COWS
# Name: question_content, dtype: object

# %%
from collections import Counter

# flatten into a single stream of tokens
all_tokens = [tok for toks in questions['tokens'] for tok in toks]

# look for tokens with ≤4 characters
unit_like = [tok for tok in all_tokens if len(tok) <= 2]

freq = Counter(unit_like)
freq.most_common(50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ruggb\.conda\envs\datakind\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tokens'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 4
#       1 from collections import Counter
#       3 # flatten into a single stream of tokens
# ----> 4 all_tokens = [tok for toks in questions['tokens'] for tok in toks]
#       6 # look for tokens with ≤4 characters
#       7 unit_like = [tok for tok in all_tokens if len(tok) <= 2]
#
# File c:\Users\ruggb\.conda\envs\datakind\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\ruggb\.conda\envs\datakind\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'tokens'

# %%
units = {"kg","g","mg","ml","l","m","cm","km","ha","acre"}

freq = Counter([tok for tok in all_tokens if tok in units])
freq.most_common(50)
# Out:
# [('l', 1138),
#  ('acre', 932),
#  ('kg', 847),
#  ('g', 163),
#  ('cm', 47),
#  ('ha', 20),
#  ('ml', 19),
#  ('km', 2)]

# %%
unit_like
# Out:
# ['l',
#  'iz',
#  'da',
#  'ov',
#  'kg',
#  'u',
#  'z',
#  'u',
#  'z',
#  'da',
#  'ca',
#  'kl',
#  'u',
#  'kg',
#  'hw',
#  'da',
#  'pa',
#  'hi',
#  'ov',
#  'b',
#  'nt',
#  'u',
#  'hw',
#  'te',
#  'n',
#  'te',
#  'b',
#  'iz',
#  'mi',
#  'ua',
#  'na',
#  'ur',
#  'sh',
#  'b',
#  'te',
#  'u',
#  'nw',
#  'ur',
#  'c',
#  'hw',
#  'e',
#  'e',
#  'hw',
#  'u',
#  'e',
#  'kg',
#  'hw',
#  'hw',
#  'hw',
#  'qi',
#  'da',
#  'u',
#  'hw',
#  'im',
#  'co',
#  'kg',
#  'n',
#  'u',
#  'l',
#  'n',
#  'u',
#  'u',
#  'gd',
#  'u',
#  'te',
#  'ö',
#  'bt',
#  'c',
#  'go',
#  'da',
#  'z',
#  'u',
#  'u',
#  'z',
#  'dc',
#  'l',
#  'n',
#  'wl',
#  'te',
#  'kj',
#  'kg',
#  'iz',
#  'e',
#  'u',
#  'de',
#  'mi',
#  'ug',
#  'mi',
#  'wz',
#  'yr',
#  'u',
#  'hw',
#  'de',
#  'de',
#  'ov',
#  'de',
#  'hv',
#  'n',
#  'da',
#  'u',
#  'ov',
#  'ov',
#  'hw',
#  'b',
#  'kg',
#  'g',
#  'dy',
#  'en',
#  'en',
#  'go',
#  'us',
#  'u',
#  'iz',
#  'wy',
#  'u',
#  'hw',
#  'hw',
#  'go',
#  'u',
#  'e',
#  'us',
#  'kg',
#  'tn',
#  'fo',
#  'u',
#  'z',
#  'hw',
#  'u',
#  'cm',
#  'l',
#  'kg',
#  'kg',
#  'eg',
#  'ft',
#  'de',
#  'de',
#  'hw',
#  'ft',
#  'ni',
#  'u',
#  'za',
#  'u',
#  'za',
#  'u',
#  'ai',
#  'e',
#  'ph',
#  'z',
#  'u',
#  'av',
#  'ni',
#  'ni',
#  'iz',
#  'hw',
#  'u',
#  'hw',
#  'te',
#  'go',
#  'ov',
#  'u',
#  'de',
#  'da',
#  'u',
#  'u',
#  'cz',
#  'go',
#  'fr',
#  'de',
#  'ak',
#  'r',
#  'mi',
#  'hw',
#  'u',
#  'wl',
#  'bt',
#  'u',
#  'mi',
#  'wt',
#  'z',
#  'ur',
#  'ok',
#  'z',
#  'e',
#  'gd',
#  'u',
#  'im',
#  'n',
#  'l',
#  'l',
#  'j',
#  'l',
#  'u',
#  'z',
#  'ov',
#  'de',
#  'ov',
#  'gu',
#  'hw',
#  'u',
#  'ur',
#  'e',
#  'hw',
#  'w',
#  'w',
#  'ad',
#  'hw',
#  'kg',
#  'im',
#  'z',
#  'im',
#  'an',
#  'r',
#  'da',
#  'ua',
#  'de',
#  'p',
#  'j',
#  'iz',
#  'ur',
#  'ml',
#  'e',
#  'l',
#  'bt',
#  'l',
#  'l',
#  'bt',
#  'go',
#  'cd',
#  'da',
#  'da',
#  'dy',
#  'ur',
#  'e',
#  'r',
#  'tn',
#  'b',
#  'si',
#  'du',
#  'e',
#  'l',
#  'l',
#  'da',
#  'b',
#  'c',
#  'ov',
#  'ov',
#  'l',
#  'hv',
#  'wz',
#  'l',
#  'kg',
#  'wt',
#  'iz',
#  'hi',
#  'e',
#  'l',
#  'de',
#  'bt',
#  'da',
#  'kg',
#  'de',
#  'l',
#  'ng',
#  'iz',
#  'gd',
#  'u',
#  'u',
#  'u',
#  'ur',
#  'hw',
#  'l',
#  'hw',
#  'ie',
#  'ok',
#  'ie',
#  'hw',
#  'de',
#  'wt',
#  'j',
#  'l',
#  'hw',
#  'z',
#  'nw',
#  'hw',
#  'ua',
#  'kg',
#  'u',
#  'ug',
#  'nd',
#  'bt',
#  'wc',
#  'wc',
#  'nt',
#  'da',
#  'dc',
#  'hw',
#  'yu',
#  'tn',
#  'hi',
#  'dk',
#  'kg',
#  'le',
#  'hw',
#  'e',
#  'tk',
#  'ug',
#  'en',
#  'u',
#  'f',
#  'u',
#  'wa',
#  'e',
#  'z',
#  'bi',
#  'de',
#  'u',
#  'j',
#  'co',
#  'hw',
#  'z',
#  'ox',
#  'go',
#  'hw',
#  'qr',
#  'n',
#  'e',
#  'ai',
#  'u',
#  'cm',
#  'mi',
#  'bt',
#  'im',
#  'im',
#  'go',
#  'iz',
#  'en',
#  'gd',
#  'hw',
#  'ie',
#  'u',
#  'u',
#  'de',
#  'u',
#  'bt',
#  'kg',
#  'cn',
#  'e',
#  'l',
#  'j',
#  'j',
#  'l',
#  'u',
#  'hw',
#  'lt',
#  'n',
#  'yy',
#  'u',
#  'z',
#  'da',
#  'un',
#  'kg',
#  'r',
#  'kg',
#  'e',
#  'ok',
#  'bt',
#  'sh',
#  'hw',
#  'cn',
#  'en',
#  'ov',
#  'iz',
#  'hw',
#  'yr',
#  'hw',
#  'j',
#  'l',
#  'w',
#  'hv',
#  'hv',
#  'u',
#  'e',
#  'u',
#  'ov',
#  'e',
#  'r',
#  'wc',
#  'c',
#  'n',
#  'l',
#  'e',
#  'hw',
#  'r',
#  'u',
#  'wl',
#  'r',
#  'hw',
#  'c',
#  'th',
#  'ok',
#  'iz',
#  'l',
#  'l',
#  'l',
#  'kg',
#  'hw',
#  'n',
#  'si',
#  'ok',
#  'z',
#  'kg',
#  'l',
#  'ok',
#  'l',
#  'e',
#  'hw',
#  'da',
#  'da',
#  'ov',
#  'l',
#  'hi',
#  'e',
#  'ov',
#  'ov',
#  'nt',
#  'wt',
#  'g',
#  'sd',
#  'iz',
#  'j',
#  'hw',
#  'ho',
#  'r',
#  'z',
#  'ic',
#  'da',
#  'da',
#  'da',
#  'n',
#  'pa',
#  'go',
#  'hw',
#  'za',
#  'g',
#  'cn',
#  'l',
#  'go',
#  'u',
#  'hw',
#  'b',
#  'ob',
#  'ya',
#  'ie',
#  'us',
#  'e',
#  'u',
#  'l',
#  'hw',
#  'ad',
#  'r',
#  'r',
#  'u',
#  'u',
#  'u',
#  'wh',
#  'l',
#  'e',
#  'iz',
#  'e',
#  'r',
#  'ta',
#  'go',
#  'iz',
#  'ov',
#  'cn',
#  'cn',
#  'uy',
#  'za',
#  'wt',
#  'l',
#  'l',
#  'ni',
#  'kg',
#  'u',
#  'z',
#  'en',
#  'c',
#  'ow',
#  'e',
#  'e',
#  'hw',
#  'go',
#  'ix',
#  'wt',
#  'eg',
#  'ix',
#  'ur',
#  'l',
#  'ov',
#  'de',
#  'hv',
#  'hw',
#  'hw',
#  'n',
#  'da',
#  'ov',
#  'iz',
#  'mi',
#  'ur',
#  'n',
#  'e',
#  'ok',
#  'ur',
#  'ur',
#  'gm',
#  'l',
#  'im',
#  'mi',
#  'hw',
#  'da',
#  'ov',
#  'bt',
#  'ao',
#  'bt',
#  'da',
#  'da',
#  'hw',
#  'e',
#  'mi',
#  'l',
#  'l',
#  'c',
#  'n',
#  'te',
#  'im',
#  'ov',
#  'mi',
#  'l',
#  'th',
#  'hw',
#  'hw',
#  'z',
#  'wa',
#  'j',
#  'en',
#  'z',
#  'wt',
#  'l',
#  'kg',
#  'na',
#  'de',
#  'nw',
#  'hw',
#  'kg',
#  'eg',
#  'gm',
#  'n',
#  'l',
#  'n',
#  'de',
#  'n',
#  'hw',
#  'im',
#  'da',
#  'l',
#  'e',
#  'l',
#  'u',
#  'u',
#  'av',
#  'u',
#  'hw',
#  'da',
#  'kg',
#  'en',
#  'dy',
#  'd',
#  'tv',
#  'j',
#  'u',
#  'na',
#  'ov',
#  'wt',
#  'b',
#  'wc',
#  'e',
#  'j',
#  'j',
#  'u',
#  'n',
#  'n',
#  'hw',
#  'kg',
#  'oo',
#  'go',
#  'kg',
#  'r',
#  'go',
#  'mr',
#  'u',
#  'us',
#  'j',
#  'ui',
#  'u',
#  'u',
#  'hw',
#  'l',
#  'im',
#  'bt',
#  'b',
#  'b',
#  'hw',
#  'kg',
#  'de',
#  'de',
#  'ok',
#  'hw',
#  'ok',
#  'ph',
#  'g',
#  'gv',
#  'g',
#  'da',
#  'da',
#  'u',
#  'kg',
#  'im',
#  'u',
#  'z',
#  'h',
#  'ph',
#  'hw',
#  'e',
#  'u',
#  'l',
#  'e',
#  'ya',
#  'hw',
#  'ug',
#  'go',
#  'ph',
#  'ml',
#  'tq',
#  'go',
#  'u',
#  'z',
#  'ov',
#  'du',
#  'u',
#  'e',
#  'bt',
#  'n',
#  'de',
#  'ov',
#  'ov',
#  'g',
#  'hw',
#  'kg',
#  'z',
#  'ar',
#  'u',
#  'u',
#  'r',
#  'e',
#  'za',
#  'na',
#  'ad',
#  'hv',
#  'l',
#  'bt',
#  'bt',
#  'yo',
#  'l',
#  'nd',
#  'nd',
#  'e',
#  'im',
#  'ai',
#  'z',
#  'da',
#  'ov',
#  'fo',
#  'go',
#  'yr',
#  'hw',
#  'n',
#  'n',
#  'te',
#  'u',
#  'u',
#  'u',
#  'n',
#  'kg',
#  'ok',
#  'u',
#  'j',
#  'eg',
#  'u',
#  'bt',
#  'go',
#  'mi',
#  'b',
#  'u',
#  'hw',
#  'j',
#  'u',
#  'p',
#  'da',
#  'e',
#  'kg',
#  'ov',
#  'l',
#  'de',
#  'ov',
#  'e',
#  'b',
#  'ov',
#  'u',
#  'en',
#  'de',
#  'l',
#  'bt',
#  'nw',
#  'e',
#  'hw',
#  'ok',
#  'e',
#  'ov',
#  'n',
#  'im',
#  'hw',
#  'wc',
#  'hw',
#  'l',
#  'fj',
#  'hw',
#  'mi',
#  'yr',
#  'im',
#  'kg',
#  'b',
#  'c',
#  'e',
#  'de',
#  'n',
#  'z',
#  'j',
#  'b',
#  'fr',
#  'ar',
#  'l',
#  'l',
#  'ok',
#  'im',
#  'ni',
#  'bg',
#  'n',
#  'b',
#  'te',
#  'hi',
#  'e',
#  'iz',
#  'th',
#  'ni',
#  'hw',
#  'hw',
#  'r',
#  'qn',
#  'n',
#  'de',
#  'ai',
#  'fo',
#  'ur',
#  'kg',
#  'b',
#  'kg',
#  'go',
#  'u',
#  'th',
#  'go',
#  'iz',
#  'hi',
#  'en',
#  'c',
#  'j',
#  'dd',
#  'de',
#  'kg',
#  'j',
#  'j',
#  'av',
#  'av',
#  'u',
#  'mi',
#  'e',
#  'wk',
#  'ok',
#  'l',
#  'u',
#  'bt',
#  'wy',
#  'l',
#  'hw',
#  'u',
#  'hi',
#  'e',
#  'ov',
#  'hw',
#  'n',
#  'ai',
#  'e',
#  'r',
#  'j',
#  'im',
#  'u',
#  'mi',
#  'l',
#  'e',
#  'ok',
#  'j',
#  'iz',
#  'u',
#  'iz',
#  'hv',
#  'hi',
#  'hw',
#  'ob',
#  'wn',
#  'da',
#  'j',
#  'mi',
#  'z',
#  'j',
#  'kg',
#  'da',
#  'kg',
#  'ov',
#  'qi',
#  'hw',
#  'u',
#  'go',
#  'hw',
#  'cn',
#  'u',
#  'hw',
#  'u',
#  'hw',
#  'da',
#  'u',
#  'gd',
#  'sh',
#  'kg',
#  'qn',
#  'e',
#  'mi',
#  'tn',
#  'dn',
#  'u',
#  'hw',
#  'iz',
#  'de',
#  'l',
#  'j',
#  'j',
#  'hw',
#  'wc',
#  'u',
#  'bt',
#  'nd',
#  'bt',
#  'hl',
#  'hw',
#  'u',
#  'ze',
#  'n',
#  'u',
#  'l',
#  'e',
#  'hw',
#  'de',
#  'ov',
#  'ap',
#  'wt',
#  'da',
#  'hw',
#  'du',
#  'u',
#  'au',
#  'gv',
#  'z',
#  'wc',
#  'wi',
#  'u',
#  'f',
#  'z',
#  'ya',
#  'na',
#  'hw',
#  'hw',
#  'ov',
#  'z',
#  'hw',
#  'hw',
#  'n',
#  'ie',
#  'hw',
#  'ar',
#  'e',
#  'u',
#  'u',
#  'hw',
#  'hw',
#  'kg',
#  'hw',
#  'l',
#  'e',
#  'wz',
#  'wz',
#  'n',
#  'wc',
#  'f',
#  'da',
#  'de',
#  'u',
#  'de',
#  'n',
#  'ov',
#  'de',
#  'en',
#  'hw',
#  'yo',
#  'ya',
#  'bt',
#  'l',
#  'hv',
#  'mi',
#  'ur',
#  'ph',
#  'l',
#  'iz',
#  'ov',
#  'u',
#  'da',
#  'ni',
#  'e',
#  'hw',
#  'bt',
#  'e',
#  'hw',
#  'e',
#  'hw',
#  'g',
#  'go',
#  'e',
#  'fr',
#  'n',
#  'ug',
#  'na',
#  'ya',
#  'wt',
#  'da',
#  'ov',
#  'u',
#  'iz',
#  'de',
#  'ov',
#  'hw',
#  'ok',
#  'kg',
#  'hv',
#  'n',
#  'hv',
#  'kg',
#  'hv',
#  'u',
#  'hw',
#  'hw',
#  'r',
#  'u',
#  'hw',
#  'z',
#  'kg',
#  'nw',
#  'u',
#  'hw',
#  'hw',
#  'u',
#  'n',
#  'hw',
#  'yr',
#  'hd',
#  'bd',
#  'ho',
#  'ya',
#  'u',
#  'iz',
#  'u',
#  'iz',
#  'hv',
#  'gd',
#  ...]

# %%
junk_terms = ["reply", "followed", "optout", "stop"]
# junk_terms = ["followed"]
mask = questions['question_content'].str.contains(
    '|'.join(junk_terms),
    case=False,
    na=False
)

junk_subset = questions[mask]
print(junk_subset.shape)
# Out:
# (3059, 28)

# %%
for a in junk_subset['question_content'].head(50):
    print(a)
# Out:
# QA farmer asks: Whats is the use of pigs fichtes in our farm? Reply Q348 followed by your response.
#
# optout stop 6333
# Now i dont have any poutry now which question am i going to reply
# Edward asks: I would like to know the pineapple disease Reply Q39 followed by your response.
#
# optout stop 6333
# A farmer asks: Am planing 2grow millet in a swampy area. How can i grow it Reply Q571 followed by your response.
# Joseph asks: where can i get/purchase a good pedigree dairy expectant heifer?..plse assist.thx. Reply Q14 followed by your response. at nandi county
# Emma Asks:what Is Cover Crops? Reply P7 Followed By Your Response.
# A farmer asks: which breed is the best of cow and where can i get Reply Q182 followed by your response.
# Beatrice asks: How Can One Determine The Age Of A Tree Plant? Reply Q816 followed by your response.
# Q A farmer asks: how do we plant passion fruits Reply Q477 followed by your response.
#
# optout stop 6333
# REPLY  Q  Can  l  use  antibiotic  to  treat  salmonellosis
# Joel asks: HOW MANY MONTH THAT IS SUPPOSSED TO HARVEST CABBAGES Reply Q293 followed by your response.
# Q What type of feeds should i give chickhens who've stop laying
# E A farmer asks: What can i give my hen to fatten early?And produce eggy early? Reply Q608 followed by your response.
# Martin asks: what is dibbling as used in crop production Reply Q1639 followed by your response.
#
# optout stop 6333
# Tumwebaze asks: what is the best type of tomatoes to plant that yields much fruits Reply Q75 followed by your response.
#
# optout stop 6333
# A farmer asks: Which herbecide i can use 2 spray my tomatoes? Reply Q258 followed by your response.
# MUSA asks: how many breeds of catle & which good to rearing s,western ug. Reply Q71 followed by your response.
#
# optout stop
# Tumwesigye asks: Whom can i contact,to sell mi yams. Reply Q72 followed by your response.
#
# optout stop 6333
# Q gai hi swali n noma nagojea jibu Benjamin asks: Michael asks: What Causes A Hen To Hatch In 18 Days? Reply Q62.Hatching depends on how eggs have been handled,give a hen eggs layed 7 days (all layed in last week)
# MY DOG IT IS CRY ALL DAY AND NIGHT WHAT CAN I DO TO STOP IT
# A farmer asks: What Causes Coffee Wilt Reply Q438 followed by your response.
#
# optout stop 6333
# A farmer asks: A,11, how can i help my cow if it was served and dint get pregnant? Reply Q188 followed by your response.
# Gilbert asks: which type of crop is suitable to be plant in kericho at this time? Reply Q15 followed by your response.
# James asks: QWhat causes black sooty stuff on maize tarsels Reply Q257 followed by your response.
# Q Ruth asks: we have a disease in our hen but attacked at de lungs,j would like to konw cause and de disease Reply Q97 followed by your response.
# What is the best stage of transplanting banana crops from the mother plant? Q reply.
# Reply,Q.what types of folier feeds did i use to increase Groundnuts to produces more flowers?
# Molly asks: Ihave ahouse of hens only but it has hooping cough, what causes that hooping cough? Reply Q3239 followed by your response.
# Aisha asks: If I What to plant maize in octomber is it good? Reply Q1639 followed by your response.
#
# optout stop 6333
# reply with Q98 how is ak kilo of ground nuts
# Doreen asks What Are weeds ? Am cute girl 4rm mbarara am what is you r name mi dia.u Are 4rm where?. REPLY Q873 followed by your response.
# Robert asks: What are the best herbicide for the control of weeds in onions Reply Q179 followed by your response.
# Rogers asks: If i do not want 2 weed my g.nut which madicine can i use 2 spray.reply q7 Reply Q435 followed by your response.
# Q, which method can we  use  to stop the change
# My  hen eat their eggs how can i stop that habit.
# Saul asks: WHAT CAN I FEED MY DUCKLIES Reply Q22 followed by your response.
# Francis asks: how much do i need to start a paultry house for layers Reply Q460 followed by your response.
#
# optout stop 6333
# Boniface asks: What are weed? Reply Q3 followed by your response.
# Q: Is it good to dig ditches at the middle of banana plantation? Reply Q897 followed by your response.
#
# optout stop 6333
# Q what can i use to stop coughing in poultry birds.
# How can i control rats in my Bean garden. Reply Q1O.
# Muhumuza asks: How is the price ov gunts and maize. Reply Q121 followed by your response.
# Q In making dairy meal, how should i mix my feeds, protein, carbohydrates, and vitamins by weight. Reply Q79 followed by your response.
# Q .How  long  does  a  milking  cow  takes  2  stop  producing  milk?
# Cornelius asks: How to plant watermelon Reply Q948 followed by your response.
# A farmer asks: How much is a kg of maize? Reply Q114 followed by your response.
# Koech asks: what are other ways of lowering soil aciddy rather than using liming elements? Reply Q22 followed by your response.
# Kato asks: I have beans where can i get ready market Reply Q78 followed by your response.
#
# optout stop 6333
# Q can layers feeds make hen stop brooding?
# How can i stop death in young local chicks between 2wks &one month.

# %%
for question in junk_subset.sample(30, random_state=42)['question_content']:
    print(question)
# Out:
# Robert asks: Somebody came to me looking for kienyeji 2days old chicks for sale andRobert asks: Somebody came to me looking for kienyeji 2days old chicks for sale and i have them, but the problem is price,how much should i sell a? Reply
# Q. I have hens that hava stop laying what is solution? but l feed with commercil food,
# Michael asks: how can you control marole in poultry? Reply Q1159 followed by your response.
# Q I want to plant onions how is the procedure Reply Q45 followed by your response.
# Q How to stop land slaind
# Nicholas asks: A farmer asks: What is the difference btn food crops & cash crops? Reply Q56 followed by your response.
# Q _my cow usualy eat polythene paperc. clothes. what wl u give it in order tw stop
# Q it rained heavy on 23rd 24th Oct but now no signs do I continue planting or stop
# Qn: If I want to plant on two arcers of land. I want to know the quantity of maize am supposed to buy and the expected yield if all goes well
#
# optout stop 6333
# Muhumuza asks: at what stage should watermelon be transplanted? Reply Q77 followed by your response.
# Reply Q  what wil I do to my maize crops attacked  by pests
# Q:how is steaming up useful 2 cattle keepers? Reply Q2 followed by your response.
# Q what can we do to stop bacteria wilt in the banana plantation?
# Benard asks: which medicine do use on eye swellen chicks? Reply Q111 followed by your response.PROPETAR
# A farmer asks: what Causes Chicks To Swollen At Around Outer Part Of Their Eyes,and What Are The Remedies For That Desease? Reply Q236 followed by your response
# E When l say that l love you what do reply
# Kato asks: What causes the change of the colour of a black goat/cow into brown? Reply Q119 followed by your response.
#
# optout stop 6333
# At what time or how many weeks should docking be done to the rams Reply Q852 followed by your response.
# Q, i want to stop some of the pest in my maize.
# A farmer asks: How long does orange seeds take to grow when on a nursery Reply Q414 followed by your response.
# ERIC ASKS:  What is the recommended spacing of coffees? Reply Q1 followed by your response.
# A farmer asks: what is the cure of goat s abortion, Reply Q9796 followed by your response.
# Matia asks: Joy Wat can i do 2 benifit from local hens Reply Q74 followed by your response.
#
# optout stop 6333
# QA farmer asks: What is the difference btn a plant and a crop? Reply Q786 followed by your response.
# Kenneth asks: what spacing should i plant melons Reply Q14 followed by your response.
# Peace asks: Who do we call ayoung fish Reply Q29 followed by your response.
#
# optout stop 6333
# William asks: What chemicals can we use ot spray sugarcane plant and avoid pests and diseases in Garden. Reply Q1226 followed by your response.
#
# optout stop 6333
# Q: Wt r the signs of a rabbit on heat Reply plz.
# Dorcas asks: A can u advice me on the best dairy cattle breed to b reared in kakamega county;that is a climatic resistant. Reply Q227 followed by your response.
# What causes rotting of cabbage in anur.bed? and what can I do to stop that problem?
