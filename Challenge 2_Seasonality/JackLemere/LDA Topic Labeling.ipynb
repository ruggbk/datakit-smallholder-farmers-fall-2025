# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import gensim
import nltk
from nltk.corpus import stopwords
from nltk.corpus import words
import spacy
import gensim.corpora as corpora
import time
from gensim.models import CoherenceModel
import pyLDAvis
import pyLDAvis.gensim_models # For Gensim integration

# %%
df = pd.read_csv('farmers_eng.csv')

# %%
df = df.sample(n=50000)

# %%
df.head()
# Out:
#          question_id  question_user_id question_language  \
# 5185806     21287361           1819302               eng
# 5249497     21508675           1852244               eng
# 2451739     12696928            114696               eng
# 5732060     23455069           1842631               eng
# 3390511     15617767           1450119               eng
#
#                                           question_content question_topic  \
# 5185806  Q as you can see now is a dry season,what type...          plant
# 5249497   my goat h've eaten alot of amaize so what can do           goat
# 2451739  Q what is the best type of maize to be  plante...          maize
# 5732060  Ihave my meize but their not grow well idont k...          maize
# 3390511  Q if in my farm i used N.P.K in planting tomat...         tomato
#
#                             question_sent  response_id  response_user_id  \
# 5185806  2019-02-05 16:01:48.529114+00:00     21287880           1054747
# 5249497  2019-02-09 18:54:41.625625+00:00     21508811           1540806
# 2451739  2018-10-04 16:36:53.737261+00:00     12698398            238040
# 5732060  2019-04-03 19:10:23.989676+00:00     23470157           1866719
# 3390511  2018-11-13 11:58:10.642499+00:00     15621389           1149751
#
#         response_language                                   response_content  \
# 5185806               eng  Q29. plant vegetables  and carry irrigation in...
# 5249497               eng                         Q172. Give It Cooking Oil.
# 2451739               eng                                           Q346PH05
# 5732060               eng                                              Q4 no
# 3390511               eng                                        Q293: D.A.P
#
#          ... question_user_country_code question_user_gender  \
# 5185806  ...                         ke                  NaN
# 5249497  ...                         ug                  NaN
# 2451739  ...                         ke                 male
# 5732060  ...                         ug                  NaN
# 3390511  ...                         ke                  NaN
#
#         question_user_dob          question_user_created_at  \
# 5185806               NaN  2019-01-10 17:51:05.891176+00:00
# 5249497               NaN  2019-01-25 11:34:19.173332+00:00
# 2451739        1992-05-25         2016-10-27 04:46:10+00:00
# 5732060               NaN  2019-01-22 14:27:58.901719+00:00
# 3390511               NaN  2018-11-10 09:15:07.391173+00:00
#
#         response_user_type response_user_status response_user_country_code  \
# 5185806             farmer                 live                         ke
# 5249497             farmer                 live                         ug
# 2451739             farmer                 live                         ke
# 5732060             farmer                 live                         ug
# 3390511             farmer                 live                         ke
#
#         response_user_gender response_user_dob  \
# 5185806                  NaN               NaN
# 5249497                  NaN               NaN
# 2451739                  NaN               NaN
# 5732060                  NaN               NaN
# 3390511                  NaN               NaN
#
#                  response_user_created_at
# 5185806  2018-08-09 12:37:04.804450+00:00
# 5249497  2018-11-27 09:55:59.392396+00:00
# 2451739         2017-06-27 16:45:18+00:00
# 5732060  2019-02-01 18:39:37.661667+00:00
# 3390511  2018-08-29 17:01:24.307357+00:00
#
# [5 rows x 24 columns]

# %%
#Drop unecessary columns, we will remove quesiton topic as we will try to categorize them differently
df = df[['question_id', 'question_content', 'question_sent', 'question_user_country_code']]

# %%
#Remove duplicate questions
df = df.drop_duplicates(subset=['question_id'], keep='first')

# %%
# Preprocess the text data
def preprocess_text(text):
    text = re.sub('\s+', ' ', text)  # Remove extra spaces
    text = re.sub('\S*@\S*\s?', '', text)  # Remove emails
    text = re.sub('\'', '', text)  # Remove apostrophes
    text = re.sub('[^a-zA-Z]', ' ', text)  # Remove non-alphabet characters
    text = text.lower()  # Convert to lowercase
    return text

# %%
df['cleaned_text'] = df['question_content'].apply(preprocess_text)

# %%
nltk.download('stopwords')
stop_words = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to C:\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
custom_stopwords = ['use','get','give','take','good','type','many','one','ask','well','want',
                    'make','know','see','look','need','help','tell','come', 'best', 'much', 'well', 'long',
                    'question', 'wont']

# %%
stop_words.extend(custom_stopwords)

# %%
def tokenize(text):
    tokens = gensim.utils.simple_preprocess(text, deacc=True)
    tokens = [token for token in tokens if token not in stop_words]
    return tokens

# %%
df['tokens'] = df['cleaned_text'].apply(tokenize)

# %% [markdown]
# search_word = 'well'
# df['contains_word'] = df['text_lemma'].apply(lambda x: search_word in x)
# df[df['contains_word']==True]

# %%
english_words = set(words.words())

def remove_non_english_tokens(token_list):
    return [word for word in token_list if word.lower() in english_words]

# %%
df['tokens'] = df['tokens'].apply(remove_non_english_tokens)

# %%
df.head()
# Out:
#          question_id                                   question_content  \
# 5185806     21287361  Q as you can see now is a dry season,what type...
# 5249497     21508675   my goat h've eaten alot of amaize so what can do
# 2451739     12696928  Q what is the best type of maize to be  plante...
# 5732060     23455069  Ihave my meize but their not grow well idont k...
# 3390511     15617767  Q if in my farm i used N.P.K in planting tomat...
#
#                             question_sent question_user_country_code  \
# 5185806  2019-02-05 16:01:48.529114+00:00                         ke
# 5249497  2019-02-09 18:54:41.625625+00:00                         ug
# 2451739  2018-10-04 16:36:53.737261+00:00                         ke
# 5732060  2019-04-03 19:10:23.989676+00:00                         ug
# 3390511  2018-11-13 11:58:10.642499+00:00                         ke
#
#                                               cleaned_text  \
# 5185806  q as you can see now is a dry season what type...
# 5249497    my goat hve eaten alot of amaize so what can do
# 2451739  q what is the best type of maize to be planted...
# 5732060  ihave my meize but their not grow well idont k...
# 3390511  q if in my farm i used n p k in planting tomat...
#
#                                                     tokens
# 5185806  [dry, season, crop, plant, earn, something, sm...
# 5249497                                      [goat, eaten]
# 2451739                                      [maize, arid]
# 5732060                                             [grow]
# 3390511  [farm, used, planting, fertilizer, planting, c...

# %%
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# %%
# Process large text as a stream via `nlp.pipe()` and iterate over the results, extracting lemmas
t0 = time.time()
lemma_text_list = []

# Convert lists of tokens back to strings if needed
# Assuming sampled_df["tokens"] contains lists of tokens
for doc in nlp.pipe(df["tokens"].apply(lambda x: " ".join(x) if isinstance(x, list) else x)):
    lemma_text_list.append(" ".join(token.lemma_ for token in doc))

df["text_lemma"] = lemma_text_list
t1 = time.time()
print("Total time: {}".format(t1-t0))
# Out:
# Total time: 14.524354934692383

# %%
df = df[df['text_lemma'].str.len() != 0]
df['text_lemma'] = df['text_lemma'].str.split()

# %%
#Apply bigrams
bigram = gensim.models.Phrases(df['text_lemma'].tolist(), min_count=5, threshold=10)
bigram_mod = gensim.models.phrases.Phraser(bigram)

# %%
df['text_lemma'] = df['text_lemma'].apply(lambda x: bigram_mod[x])

# %%
def remove_stopwords_from_list(word_list):
    return [word for word in word_list if word.lower() not in stop_words]

# %%
df['text_lemma'] = df['text_lemma'].apply(remove_stopwords_from_list)

# %%
df.head()
# Out:
#          question_id                                   question_content  \
# 5185806     21287361  Q as you can see now is a dry season,what type...
# 5249497     21508675   my goat h've eaten alot of amaize so what can do
# 2451739     12696928  Q what is the best type of maize to be  plante...
# 5732060     23455069  Ihave my meize but their not grow well idont k...
# 3390511     15617767  Q if in my farm i used N.P.K in planting tomat...
#
#                             question_sent question_user_country_code  \
# 5185806  2019-02-05 16:01:48.529114+00:00                         ke
# 5249497  2019-02-09 18:54:41.625625+00:00                         ug
# 2451739  2018-10-04 16:36:53.737261+00:00                         ke
# 5732060  2019-04-03 19:10:23.989676+00:00                         ug
# 3390511  2018-11-13 11:58:10.642499+00:00                         ke
#
#                                               cleaned_text  \
# 5185806  q as you can see now is a dry season what type...
# 5249497    my goat hve eaten alot of amaize so what can do
# 2451739  q what is the best type of maize to be planted...
# 5732060  ihave my meize but their not grow well idont k...
# 3390511  q if in my farm i used n p k in planting tomat...
#
#                                                     tokens  \
# 5185806  [dry, season, crop, plant, earn, something, sm...
# 5249497                                      [goat, eaten]
# 2451739                                      [maize, arid]
# 5732060                                             [grow]
# 3390511  [farm, used, planting, fertilizer, planting, c...
#
#                                                 text_lemma
# 5185806  [dry, season, crop, plant, earn, something, sm...
# 5249497                                        [goat, eat]
# 2451739                                      [maize, arid]
# 5732060                                             [grow]
# 3390511  [farm, planting, fertilizer, planting, course,...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47018 entries, 5185806 to 7865601
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   question_id                 47018 non-null  int64
#  1   question_content            47018 non-null  object
#  2   question_sent               47018 non-null  object
#  3   question_user_country_code  47018 non-null  object
#  4   cleaned_text                47018 non-null  object
#  5   tokens                      47018 non-null  object
#  6   text_lemma                  47018 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 2.9+ MB

# %%
# Create dictionary and corpus
id2word = corpora.Dictionary(df['text_lemma'])
id2word.filter_extremes(no_below=10, no_above=0.4)
texts = df['text_lemma']
corpus = [id2word.doc2bow(text) for text in texts]

# %%
t0 = time.time()
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                            id2word=id2word,
                                            num_topics=7,
                                            chunksize=100,
                                            passes=100,
                                            iterations=1000,
                                            alpha='auto',
                                            eta='auto',
                                            eval_every=None)
t1 = time.time()
print("Total time: {}".format(t1-t0))
# Out:
# Total time: 374.96100091934204

# %%
# Print the topics
topics = lda_model.print_topics(num_words=5)
for topic in topics:
    print(topic)
# Out:
# (0, '0.154*"cow" + 0.055*"chicken" + 0.050*"disease" + 0.039*"farming" + 0.034*"goat"')
# (1, '0.049*"time" + 0.035*"like" + 0.035*"eat" + 0.035*"fertilizer" + 0.034*"wat"')
# (2, '0.112*"control" + 0.076*"potato" + 0.062*"medicine" + 0.056*"sheep" + 0.044*"prevent"')
# (3, '0.064*"poultry" + 0.056*"coffee" + 0.050*"keep" + 0.047*"start" + 0.047*"price"')
# (4, '0.221*"plant" + 0.209*"maize" + 0.022*"soil" + 0.022*"county" + 0.021*"cost"')
# (5, '0.104*"grow" + 0.071*"crop" + 0.055*"farm" + 0.051*"season" + 0.045*"market"')
# (6, '0.064*"planting" + 0.062*"milk" + 0.061*"banana" + 0.051*"farmer" + 0.046*"seed"')

# %%
# Compute coherence score
t0 = time.time()
coherence_model_lda = CoherenceModel(model=lda_model, texts=texts, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
t1 = time.time()
print("Total time: {}".format(t1-t0))
# Out:
# Coherence Score:  0.295629063080916
# Total time: 4.6288902759552

# %%
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, id2word)
pyLDAvis.enable_notebook()
pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1796018421531456805196125458" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el1796018421531456805196125458_data = {"mdsDat": {"x": [0.4426294581990511, -0.09298496586831656, -0.09627096367975815, -0.0943155115192416, -0.06781480971230731, -0.06509885379238328, -0.026144353627044384], "y": [-0.013028790218048631, -0.43067467627736267, 0.146668164547543, 0.09142085137272803, 0.0678846606455686, 0.08555140291402573, 0.052178387015545676], "topics": [1, 2, 3, 4, 5, 6, 7], "cluster": [1, 1, 1, 1, 1, 1, 1], "Freq": [21.86297244407922, 14.909329826127571, 14.190990800177353, 14.167266690440835, 13.045340589413376, 12.793544566376989, 9.03055508338466]}, "tinfo": {"Term": ["plant", "maize", "cow", "grow", "control", "crop", "poultry", "planting", "potato", "milk", "banana", "farm", "coffee", "chicken", "season", "keep", "disease", "farmer", "medicine", "start", "price", "time", "market", "tomato", "sheep", "seed", "reply_response", "cattle", "feed", "dairy", "plant", "maize", "soil", "county", "cost", "affect", "variety", "mature", "spray", "method", "could", "watermelon", "egg", "yellow", "area", "rainy_season", "wen", "place", "hybrid", "consider", "growth", "together", "even", "low", "kill", "short", "suppose", "shamba", "da", "without", "flowering", "grow", "crop", "farm", "season", "market", "tomato", "what_s", "production", "apply", "name", "improve", "sell", "leave", "leaf", "high", "rain", "go", "money", "crop_rotation", "spinach", "de", "black", "region", "thank", "passion", "sex", "also", "onion", "fall", "thus", "poultry", "coffee", "keep", "start", "price", "feed", "dairy", "livestock", "day", "breed", "two", "chemical", "effect", "possible", "bee", "treat", "find", "tea", "tree", "sweet_potato", "order", "house", "would", "old", "advice", "salt", "flower", "follow", "within", "sale", "cow", "chicken", "disease", "farming", "goat", "dry", "problem", "garden", "cause", "calf", "bean", "heat", "water", "apart", "wilt", "dog", "may", "answer", "white", "small", "cat", "heifer", "weed", "three", "cotton", "camel", "could_problem", "cover", "age", "green", "time", "like", "eat", "fertilizer", "wat", "hen", "animal", "pig", "harvest", "rice", "young", "banana_plantation", "do_not", "big", "buy", "per", "yield", "chick", "bull", "die", "fish", "ready", "year", "first", "urea", "period", "would_like", "lay", "te", "stomach", "planting", "milk", "banana", "farmer", "seed", "reply_response", "cattle", "cabbage", "suitable", "grass", "acre", "month", "stop", "produce", "manure", "space", "stage", "plantation", "call", "advisable", "increase", "prepare", "another", "treatment", "water_melon", "amount", "importance", "number", "skin", "give_birth", "control", "potato", "medicine", "sheep", "prevent", "way", "food", "rabbit", "kind", "land", "please", "put", "birth", "local", "protect", "pest", "deworm", "hard", "care", "major", "meat", "head", "watery", "coz", "colour", "show", "banana_wilt", "climate", "sack", "require"], "Freq": [7031.0, 6652.0, 3172.0, 2246.0, 1467.0, 1545.0, 1313.0, 1187.0, 998.0, 1151.0, 1135.0, 1199.0, 1150.0, 1138.0, 1106.0, 1036.0, 1020.0, 955.0, 812.0, 980.0, 965.0, 921.0, 976.0, 939.0, 739.0, 850.0, 842.0, 833.0, 858.0, 826.0, 7030.439177148884, 6651.40004635785, 712.1160280698214, 687.5421477529637, 677.4774164441018, 660.7039692796305, 634.90428969673, 564.6240267599753, 512.5850089691247, 466.41949180016564, 416.2210080258395, 399.76832163420124, 357.2903546067389, 343.35743248123026, 327.08713308619593, 315.51002820082067, 294.49485502055603, 228.39729835418274, 215.2672105188211, 214.51908936778844, 201.4405032159858, 201.64508921412386, 196.7591333744773, 196.1080070608142, 194.2721496339463, 194.03441312685072, 193.4028959312094, 191.67923225809471, 184.70167169457335, 166.82924076015624, 167.3258472238078, 2245.8844542626402, 1544.4727602022228, 1198.786188211163, 1105.5008377803451, 975.4992163306881, 938.6570738722422, 823.1598953417865, 583.8008603551924, 440.33373997918835, 381.67042301990995, 360.95189524820466, 353.9209378554689, 353.7741551247408, 337.174485 ...

# %%
print("Documents:", len(texts))
print("Avg tokens per doc:", sum(len(t) for t in texts) / len(texts))
print("Vocab size:", len(id2word))
# Out:
# Documents: 47018
# Avg tokens per doc: 3.3222382917180653
# Vocab size: 1500

# %%
from collections import Counter
print(Counter([w for doc in texts for w in doc]).most_common(20))
# Out:
# [('plant', 7379), ('maize', 7177), ('cow', 3069), ('grow', 2056), ('crop', 1667), ('farm', 1550), ('control', 1466), ('poultry', 1290), ('planting', 1249), ('chicken', 1202), ('season', 1154), ('time', 1036), ('start', 1031), ('milk', 1020), ('banana', 1012), ('coffee', 1002), ('feed', 988), ('price', 984), ('what_s', 939), ('potato', 892)]
